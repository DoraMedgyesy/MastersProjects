# %% [markdown]
# # A2.2

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

os.makedirs('./results', exist_ok=True)

with open('./brown_100.txt', 'r') as file_:
    corpus = file_.read()

def write_freqs(list_: list, filename: str) -> None:
    with open(f'./results/{filename}.txt', 'w') as file_:
        file_.write('\n'.join([' '.join(x[0]) + ' | ' + str(x[1]) for x in list_]))

# %% [markdown]
# ## N-Gram Language Modeling
# In the second assignment, you will implement an **n-gram language model** that processes input text to generate, analyze, and calculate the probabilities of sequences of `n` words (n-grams). This model will tokenize text, create n-grams, and compute their frequencies and probabilities, returning the most frequent n-grams in the text.
#
# 1. **Tokenization**: Convert the input text into a list of words (tokens).
# 2. **N-gram Generation**: Create sequences of `n` tokens from the text, treating each sentence independently with the inclusion of start (`<s>`) and end (`</s>`) markers.
# 3. **Frequency Counting**: Count how many times each n-gram appears in the text.
# 4. **Probability Calculation**: Compute the probabilities of each n-gram based on its frequency and add alpha smoothing to improve generalization of items.
# 5. **Most Frequent N-grams**: Return the most frequent n-grams along with their probabilities, helping to identify common patterns in the text.

# %%
import nltk
from collections import Counter, defaultdict

nltk.download('punkt')
nltk.download('punkt_tab')

class NGramModel:
    def __init__(self, text, n, alpha=0.0):
        """
        Initialize the NGramModel with text and the value of n.
        """
        self.text = text
        self.n = n
        self.alpha = alpha  # Alpha value for additive smoothing
        self.ngrams = {}
        self.probabilities = {}
        self.vocab = set()

    def tokenize(self) -> None:
        """
        Tokenize the text into words.
        Fill in the code to split the text into a list of words.
        """
        cleaned_text = self.text.replace('<s>', '').replace('</s>', '')
        sentences = nltk.sent_tokenize(cleaned_text)
        tokens = [nltk.word_tokenize(sent.lower()) for sent in sentences]
        return tokens

    def generate_ngrams(self, tokens: list) -> dict:
        """
        Generate n-grams from the list of tokens.
        Fill in the code to create n-grams.
        Make sure to treat each sentence independently, include the <s> and </s> tokens.
        """
        ngram_list = []
        for sentence in tokens:
            padded_tokens = ['<s>'] * (self.n - 1) + sentence + ['</s>']

            self.vocab.update(padded_tokens)

            for i in range(len(padded_tokens)- self.n + 1):
                ngram_list.append(tuple(padded_tokens[i:i+self.n]))

        self.ngrams = ngram_list
        return self.ngrams

    def count_frequencies(self) -> None:
        """
        Count the frequencies of each n-gram.
        Fill in the code to count n-gram occurrences.
        """
        self.ngrams = Counter(self.ngrams)


    def calculate_probabilities(self) -> None:
        """
        Calculate probabilities of each n-gram based on its frequency. Add alpha smoothing separately.
        """
        self.probabilities = {}
        words_count = Counter()
        vocab_size = len(self.vocab)

        for ngram, num in self.ngrams.items():
            word = ngram[:-1]
            words_count[word] += num

        for ngram, num in self.ngrams.items():
            word = ngram[:-1]
            numerator = num + self.alpha
            denominator = words_count[word] + self.alpha * vocab_size
            self.probabilities[ngram] = numerator / denominator



    def most_frequent_ngrams(self, top_n: int = 10) -> list:
        """
        Return the most frequent n-grams and their probabilities.
        """
        sort_ngrams = sorted(self.ngrams.items(), key=lambda x: x[1], reverse=True)[:top_n]

        sorted_grams = []
        for ngram, freq in sort_ngrams:
            prob = self.probabilities.get(ngram)
            sorted_grams.append((ngram, freq, prob))

        return sorted_grams


text = "This is a simple example to demonstrate how n-grams work in this assignment."
n = 2
model = NGramModel(text, n)

tokens = model.tokenize()
ngrams = model.generate_ngrams(tokens)
model.count_frequencies()
model.calculate_probabilities()

print(model.most_frequent_ngrams(10))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [(('<s>', 'this'), 1, 1.0), (('this', 'is'), 1, 0.5), (('is', 'a'), 1, 1.0), (('a', 'simple'), 1, 1.0), (('simple', 'example'), 1, 1.0), (('example', 'to'), 1, 1.0), (('to', 'demonstrate'), 1, 1.0), (('demonstrate', 'how'), 1, 1.0), (('how', 'n-grams'), 1, 1.0), (('n-grams', 'work'), 1, 1.0)]

# %%
import math

def perplexity(model, tokens):
    n = model.n
    sum_probability_log = 0
    word_count = 0

    for sentence in tokens:
        padded = ['<s>'] * (n - 1) + sentence + ['</s>']

        for i in range(len(padded) - n + 1):
            ngram = tuple(padded[i:i+n])

            if ngram in model.probabilities:
                prob = model.probabilities[ngram]

            else:
                vocab_size = len(model.vocab)
                if vocab_size == 0:
                    vocab_size = 1

                alpha = model.alpha
                if alpha == 0:
                  alpha = 1e-8
                denominator = alpha * vocab_size
                prob = alpha / (alpha * vocab_size)

            sum_probability_log += math.log(prob)
            word_count += 1

    return math.exp(-sum_probability_log / word_count)

# %% [markdown]
# ### Unigrams
#
# In this section, we apply the `NGramModel` to our corpus. The model can be configured to generate unigrams, bigrams, or trigrams by adjusting the value of `n`. After tokenizing the text and generating the n-grams, the model counts the occurrences of each n-gram and calculates their probabilities. The most frequent n-grams are then written to an output file.
#
# By adjusting the n-gram size, we can analyze different levels of word dependencies in the text, providing insights into common word sequences and patterns.
#
# The code below will generate unigrams when the NGramModel is implemented correctly

# %%
n = 1  # You can change this to 1, 2, or 3 for uni, bi, or trigrams
model = NGramModel(corpus, n)

tokens = model.tokenize()
ngrams = model.generate_ngrams(tokens)
model.count_frequencies()
model.calculate_probabilities()

write_freqs(model.most_frequent_ngrams(10), 'unigrams')
#for ngram, prob in model.probabilities.items():
    #print(f"{ngram}: {prob:.4f}")

unigram_perplexity = perplexity(model, tokens)
print("Perplexity:", unigram_perplexity)
# Out:
# Perplexity: 266.71699436815993

# %% [markdown]
# ### Bigrams
# Bigrams allow us to explore word pairs and their relationships, providing insight into common word combinations and phrase structures within the corpus.
# The code below will generate bigrams when the NGramModel is implemented correctly.

# %%
n = 2  # You can change this to 1, 2, or 3 for uni, bi, or trigrams
model = NGramModel(corpus, n)

tokens = model.tokenize()
ngrams = model.generate_ngrams(tokens)
model.count_frequencies()
model.calculate_probabilities()

write_freqs(model.most_frequent_ngrams(10), 'bigrams')


bigram_perplexity = perplexity(model, tokens)
print("Perplexity:", bigram_perplexity)
# Out:
# Perplexity: 5.335748895915144

# %% [markdown]
# ### Trigrams
# Trigrams capture three-word sequences, providing a deeper understanding of longer word dependencies and commonly occurring phrases within the text.
# The code below will generate trigrams when the NGramModel is implemented correctly

# %%
n = 3  # You can change this to 1, 2, or 3 for uni, bi, or trigrams
model = NGramModel(corpus, n)

tokens = model.tokenize()
ngrams = model.generate_ngrams(tokens)
model.count_frequencies()
model.calculate_probabilities()

write_freqs(model.most_frequent_ngrams(10), 'trigrams')
trigram_perplexity = perplexity(model, tokens)
print("Perplexity:", trigram_perplexity)
# Out:
# Perplexity: 1.472548321158181

# %% [markdown]
# ### Smoothing
# Below, we generate **bigrams** with **smoothing** applied by setting `n = 2` and including a smoothing parameter `alpha = 1.0`. Smoothing is useful in language models to handle unseen n-grams by assigning a small probability to them. The model tokenizes the text, generates bigrams, counts their frequencies, and calculates smoothed probabilities. The most frequent bigrams are then written to an output file.

# %%
n = 2  # You can change this to 1, 2, or 3 for uni, bi, or trigrams
model = NGramModel(corpus, n, alpha=3)

tokens = model.tokenize()
ngrams = model.generate_ngrams(tokens)
model.count_frequencies()
model.calculate_probabilities()

write_freqs(model.most_frequent_ngrams(10), 'bigrams_smoothed')

#smoothing_perplexity = perplexity(model, tokens)
#print("Perplexity:", smoothing_perplexity)

for ngram, prob in model.probabilities.items():
    print(f"{ngram}: {prob:.4f}")
# Out:
# ('<s>', 'the'): 0.0108
# ('the', 'fulton'): 0.0035
# ('fulton', 'county'): 0.0037
# ('county', 'grand'): 0.0017
# ('grand', 'jury'): 0.0025
# ('jury', 'said'): 0.0045
# ('said', 'friday'): 0.0016
# ('friday', 'an'): 0.0017
# ('an', 'investigation'): 0.0017
# ('investigation', 'of'): 0.0017
# ('of', 'atlanta'): 0.0024
# ('atlanta', "'s"): 0.0021
# ("'s", 'recent'): 0.0016
# ('recent', 'primary'): 0.0017
# ('primary', 'election'): 0.0017
# ('election', 'produced'): 0.0017
# ('produced', '``'): 0.0017
# ('``', 'no'): 0.0016
# ('no', 'evidence'): 0.0017
# ('evidence', '``'): 0.0017
# ('``', 'that'): 0.0020
# ('that', 'any'): 0.0016
# ('any', 'irregularities'): 0.0017
# ('irregularities', 'took'): 0.0017
# ('took', 'place'): 0.0017
# ('place', '.'): 0.0017
# ('.', '</s>'): 0.0388
# ('the', 'jury'): 0.0062
# ('jury', 'further'): 0.0016
# ('further', 'said'): 0.0017
# ('said', 'in'): 0.0016
# ('in', 'term-end'): 0.0016
# ('term-end', 'presentments'): 0.0017
# ('presentments', 'that'): 0.0017
# ('that', 'the'): 0.0033
# ('the', 'city'): 0.0027
# ('city', 'executive'): 0.0017
# ('executive', 'committee'): 0.0021
# ('committee', ','): 0.0017
# (',', 'which'): 0.0024
# ('which', 'had'): 0.0017
# ('had', 'over-all'): 0.0017
# ('over-all', 'charge'): 0.0017
# ('charge', 'of'): 0.0017
# ('of', 'the'): 0.0069
# ('the', 'election'): 0.0035
# ('election', ','): 0.0025
# (',', '``'): 0.0028
# ('``', 'deserves'): 0.0016
# ('deserves', 'the'): 0.0017
# ('the', 'praise'): 0.0016
# ('praise', 'and'): 0.0017
# ('and', 'thanks'): 0.0016
# ('thanks', 'of'): 0.0017
# ('city', 'of'): 0.0017
# ('atlanta', '``'): 0.0017
# ('``', 'for'): 0.0016
# ('for', 'the'): 0.0025
# ('the', 'manner'): 0.0016
# ('manner', 'in'): 0.0017
# ('in', 'which'): 0.0016
# ('which', 'the'): 0.0025
# ('election', 'was'): 0.0021
# ('was', 'conducted'): 0.0016
# ('conducted', '.'): 0.0017
# ('the', 'september-october'): 0.0016
# ('september-october', 'term'): 0.0017
# ('term', 'jury'): 0.0017
# ('jury', 'had'): 0.0016
# ('had', 'been'): 0.0021
# ('been', 'charged'): 0.0017
# ('charged', 'by'): 0.0017
# ('by', 'fulton'): 0.0017
# ('fulton', 'superior'): 0.0021
# ('superior', 'court'): 0.0021
# ('court', 'judge'): 0.0017
# ('judge', 'durwood'): 0.0017
# ('durwood', 'pye'): 0.0017
# ('pye', 'to'): 0.0017
# ('to', 'investigate'): 0.0016
# ('investigate', 'reports'): 0.0017
# ('reports', 'of'): 0.0017
# ('of', 'possible'): 0.0016
# ('possible', '``'): 0.0017
# ('``', 'irregularities'): 0.0016
# ('irregularities', '``'): 0.0017
# ('``', 'in'): 0.0020
# ('in', 'the'): 0.0078
# ('the', 'hard-fought'): 0.0016
# ('hard-fought', 'primary'): 0.0017
# ('primary', 'which'): 0.0017
# ('which', 'was'): 0.0017
# ('was', 'won'): 0.0016
# ('won', 'by'): 0.0017
# ('by', 'mayor-nominate'): 0.0017
# ('mayor-nominate', 'ivan'): 0.0017
# ('ivan', 'allen'): 0.0021
# ('allen', 'jr.'): 0.0021
# ('jr.', '.'): 0.0017
# ('<s>', '``'): 0.0044
# ('``', 'only'): 0.0016
# ('only', 'a'): 0.0017
# ('a', 'relative'): 0.0016
# ('relative', 'handful'): 0.0017
# ('handful', 'of'): 0.0017
# ('of', 'such'): 0.0016
# ('such', 'reports'): 0.0017
# ('reports', 'was'): 0.0017
# ('was', 'received'): 0.0016
# ('received', '``'): 0.0017
# ('``', ','): 0.0040
# (',', 'the'): 0.0076
# ('said', ','): 0.0025
# ('``', 'considering'): 0.0016
# ('considering', 'the'): 0.0017
# ('the', 'widespread'): 0.0016
# ('widespread', 'interest'): 0.0017
# ('interest', 'in'): 0.0017
# ('the', 'number'): 0.0019
# ('number', 'of'): 0.0025
# ('of', 'voters'): 0.0016
# ('voters', 'and'): 0.0017
# ('and', 'the'): 0.0024
# ('the', 'size'): 0.0016
# ('size', 'of'): 0.0017
# ('of', 'this'): 0.0020
# ('this', 'city'): 0.0017
# ('city', '``'): 0.0021
# ('``', '.'): 0.0073
# ('said', 'it'): 0.0025
# ('it', 'did'): 0.0016
# ('did', 'find'): 0.0017
# ('find', 'that'): 0.0017
# ('that', 'many'): 0.0016
# ('many', 'of'): 0.0017
# ('of', 'georgia'): 0.0028
# ('georgia', "'s"): 0.0029
# ("'s", 'registration'): 0.0016
# ('registration', 'and'): 0.0017
# ('and', 'election'): 0.0016
# ('election', 'laws'): 0.0017
# ('laws', '``'): 0.0017
# ('``', 'are'): 0.0024
# ('are', 'outmoded'): 0.0017
# ('outmoded', 'or'): 0.0017
# ('or', 'inadequate'): 0.0017
# ('inadequate', 'and'): 0.0017
# ('and', 'often'): 0.0016
# ('often', 'ambiguous'): 0.0017
# ('ambiguous', '``'): 0.0017
# ('<s>', 'it'): 0.0036
# ('it', 'recommended'): 0.0016
# ('recommended', 'that'): 0.0021
# ('that', 'fulton'): 0.0016
# ('fulton', 'legislators'): 0.0021
# ('legislators', 'act'): 0.0017
# ('act', '``'): 0.0017
# ('``', 'to'): 0.0020
# ('to', 'have'): 0.0016
# ('have', 'these'): 0.0017
# ('these', 'laws'): 0.0017
# ('laws', 'studied'): 0.0017
# ('studied', 'and'): 0.0017
# ('and', 'revised'): 0.0016
# ('revised', 'to'): 0.0017
# ('to', 'the'): 0.0028
# ('the', 'end'): 0.0016
# ('end', 'of'): 0.0017
# ('of', 'modernizing'): 0.0016
# ('modernizing', 'and'): 0.0017
# ('and', 'improving'): 0.0016
# ('improving', 'them'): 0.0017
# ('them', '``'): 0.0017
# ('the', 'grand'): 0.0019
# ('jury', 'commented'): 0.0016
# ('commented', 'on'): 0.0021
# ('on', 'a'): 0.0017
# ('a', 'number'): 0.0016
# ('of', 'other'): 0.0016
# ('other', 'topics'): 0.0017
# ('topics', ','): 0.0017
# (',', 'among'): 0.0016
# ('among', 'them'): 0.0017
# ('them', 'the'): 0.0017
# ('the', 'atlanta'): 0.0023
# ('atlanta', 'and'): 0.0017
# ('and', 'fulton'): 0.0016
# ('county', 'purchasing'): 0.0017
# ('purchasing', 'departments'): 0.0017
# ('departments', 'which'): 0.0017
# ('which', 'it'): 0.0017
# ('it', 'said'): 0.0016
# ('said', '``'): 0.0016
# ('are', 'well'): 0.0017
# ('well', 'operated'): 0.0017
# ('operated', 'and'): 0.0017
# ('and', 'follow'): 0.0016
# ('follow', 'generally'): 0.0017
# ('generally', 'accepted'): 0.0017
# ('accepted', 'practices'): 0.0017
# ('practices', 'which'): 0.0017
# ('which', 'inure'): 0.0017
# ('inure', 'to'): 0.0017
# ('the', 'best'): 0.0016
# ('best', 'interest'): 0.0017
# ('interest', 'of'): 0.0017
# ('of', 'both'): 0.0016
# ('both', 'governments'): 0.0017
# ('governments', '``'): 0.0017
# ('<s>', 'merger'): 0.0016
# ('merger', 'proposed'): 0.0017
# ('proposed', 'however'): 0.0017
# ('however', ','): 0.0021
# ('it', 'believes'): 0.0016
# ('believes', '``'): 0.0017
# ('``', 'these'): 0.0020
# ('these', 'two'): 0.0017
# ('two', 'offices'): 0.0017
# ('offices', 'should'): 0.0017
# ('should', 'be'): 0.0029
# ('be', 'combined'): 0.0016
# ('combined', 'to'): 0.0017
# ('to', 'achieve'): 0.0016
# ('achieve', 'greater'): 0.0017
# ('greater', 'efficiency'): 0.0017
# ('efficiency', 'and'): 0.0017
# ('and', 'reduce'): 0.0016
# ('reduce', 'the'): 0.0017
# ('the', 'cost'): 0.0016
# ('cost', 'of'): 0.0017
# ('of', 'administration'): 0.0016
# ('administration', '``'): 0.0017
# ('city', 'purchasing'): 0.0017
# ('purchasing', 'department'): 0.0017
# ('department', ','): 0.0021
# ('``', 'is'): 0.0016
# ('is', 'lacking'): 0.0017
# ('lacking', 'in'): 0.0017
# ('in', 'experienced'): 0.0016
# ('experienced', 'clerical'): 0.0017
# ('clerical', 'personnel'): 0.0017
# ('personnel', 'as'): 0.0017
# ('as', 'a'): 0.0025
# ('a', 'result'): 0.0016
# ('result', 'of'): 0.0017
# ('of', 'city'): 0.0016
# ('city', 'personnel'): 0.0017
# ('personnel', 'policies'): 0.0017
# ('policies', '``'): 0.0017
# ('it', 'urged'): 0.0021
# ('urged', 'that'): 0.0021
# ('``', 'take'): 0.0016
# ('take', 'steps'): 0.0017
# ('steps', 'to'): 0.0017
# ('to', 'remedy'): 0.0016
# ('remedy', '``'): 0.0017
# ('``', 'this'): 0.0024
# ('this', 'problem'): 0.0017
# ('problem', '.'): 0.0017
# ('<s>', 'implementation'): 0.0016
# ('implementation', 'of'): 0.0021
# ("'s", 'automobile'): 0.0016
# ('automobile', 'title'): 0.0017
# ('title', 'law'): 0.0017
# ('law', 'was'): 0.0017
# ('was', 'also'): 0.0016
# ('also', 'recommended'): 0.0017
# ('recommended', 'by'): 0.0017
# ('by', 'the'): 0.0017
# ('the', 'outgoing'): 0.0016
# ('outgoing', 'jury'): 0.0017
# ('jury', '.'): 0.0016
# ('the', 'next'): 0.0016
# ('next', 'legislature'): 0.0017
# ('legislature', '``'): 0.0017
# ('``', 'provide'): 0.0016
# ('provide', 'enabling'): 0.0017
# ('enabling', 'funds'): 0.0017
# ('funds', 'and'): 0.0017
# ('and', 're-set'): 0.0016
# ('re-set', 'the'): 0.0017
# ('the', 'effective'): 0.0016
# ('effective', 'date'): 0.0017
# ('date', 'so'): 0.0017
# ('so', 'that'): 0.0017
# ('that', 'an'): 0.0021
# ('an', 'orderly'): 0.0021
# ('orderly', 'implementation'): 0.0017
# ('the', 'law'): 0.0016
# ('law', 'may'): 0.0017
# ('may', 'be'): 0.0017
# ('be', 'effected'): 0.0016
# ('effected', '``'): 0.0017
# ('jury', 'took'): 0.0016
# ('took', 'a'): 0.0017
# ('a', 'swipe'): 0.0016
# ('swipe', 'at'): 0.0017
# ('at', 'the'): 0.0037
# ('the', 'state'): 0.0035
# ('state', 'welfare'): 0.0021
# ('welfare', 'department'): 0.0021
# ('department', "'s"): 0.0017
# ("'s", 'handling'): 0.0016
# ('handling', 'of'): 0.0017
# ('of', 'federal'): 0.0016
# ('federal', 'funds'): 0.0021
# ('funds', 'granted'): 0.0017
# ('granted', 'for'): 0.0017
# ('for', 'child'): 0.0016
# ('child', 'welfare'): 0.0017
# ('welfare', 'services'): 0.0017
# ('services', 'in'): 0.0017
# ('in', 'foster'): 0.0016
# ('foster', 'homes'): 0.0017
# ('homes', '.'): 0.0017
# ('this', 'is'): 0.0017
# ('is', 'one'): 0.0017
# ('one', 'of'): 0.0021
# ('the', 'major'): 0.0016
# ('major', 'items'): 0.0017
# ('items', 'in'): 0.0017
# ('county', 'general'): 0.0017
# ('general', 'assistance'): 0.0017
# ('assistance', 'program'): 0.0017
# ('program', '``'): 0.0017
# (',', 'but'): 0.0020
# ('but', 'the'): 0.0017
# ('department', '``'): 0.0017
# ('``', 'has'): 0.0020
# ('has', 'seen'): 0.0017
# ('seen', 'fit'): 0.0017
# ('fit', 'to'): 0.0017
# ('to', 'distribute'): 0.0016
# ('distribute', 'these'): 0.0017
# ('these', 'funds'): 0.0021
# ('funds', 'through'): 0.0017
# ('through', 'the'): 0.0017
# ('the', 'welfare'): 0.0016
# ('welfare', 'departments'): 0.0017
# ('departments', 'of'): 0.0017
# ('of', 'all'): 0.0016
# ('all', 'the'): 0.0017
# ('the', 'counties'): 0.0016
# ('counties', 'in'): 0.0017
# ('state', 'with'): 0.0017
# ('with', 'the'): 0.0021
# ('the', 'exception'): 0.0016
# ('exception', 'of'): 0.0021
# ('of', 'fulton'): 0.0016
# ('county', ','): 0.0017
# ('which', 'receives'): 0.0017
# ('receives', 'none'): 0.0017
# ('none', 'of'): 0.0021
# ('this', 'money'): 0.0017
# ('money', '.'): 0.0017
# ('the', 'jurors'): 0.0019
# ('jurors', 'said'): 0.0021
# ('said', 'they'): 0.0016
# ('they', 'realize'): 0.0017
# ('realize', '``'): 0.0017
# ('``', 'a'): 0.0020
# ('a', 'proportionate'): 0.0016
# ('proportionate', 'distribution'): 0.0017
# ('distribution', 'of'): 0.0017
# ('of', 'these'): 0.0020
# ('funds', 'might'): 0.0017
# ('might', 'disable'): 0.0017
# ('disable', 'this'): 0.0017
# ('this', 'program'): 0.0017
# ('program', 'in'): 0.0017
# ('in', 'our'): 0.0016
# ('our', 'less'): 0.0017
# ('less', 'populous'): 0.0017
# ('populous', 'counties'): 0.0017
# ('counties', '``'): 0.0017
# ('<s>', 'nevertheless'): 0.0016
# ('nevertheless', ','): 0.0017
# ('``', 'we'): 0.0016
# ('we', 'feel'): 0.0017
# ('feel', 'that'): 0.0017
# ('that', 'in'): 0.0016
# ('the', 'future'): 0.0016
# ('future', 'fulton'): 0.0017
# ('county', 'should'): 0.0017
# ('should', 'receive'): 0.0017
# ('receive', 'some'): 0.0017
# ('some', 'portion'): 0.0017
# ('portion', 'of'): 0.0021
# ('these', 'available'): 0.0017
# ('available', 'funds'): 0.0017
# ('funds', '``'): 0.0021
# ('said', '.'): 0.0029
# ('``', 'failure'): 0.0016
# ('failure', 'to'): 0.0017
# ('to', 'do'): 0.0016
# ('do', 'this'): 0.0017
# ('this', 'will'): 0.0017
# ('will', 'continue'): 0.0017
# ('continue', 'to'): 0.0017
# ('to', 'place'): 0.0020
# ('place', 'a'): 0.0017
# ('a', 'disproportionate'): 0.0016
# ('disproportionate', 'burden'): 0.0017
# ('burden', '``'): 0.0017
# ('``', 'on'): 0.0016
# ('on', 'fulton'): 0.0017
# ('fulton', 'taxpayers'): 0.0017
# ('taxpayers', '.'): 0.0017
# ('jury', 'also'): 0.0016
# ('also', 'commented'): 0.0017
# ('on', 'the'): 0.0029
# ('fulton', 'ordinary'): 0.0017
# ('ordinary', "'s"): 0.0017
# ("'s", 'court'): 0.0016
# ('court', 'which'): 0.0017
# ('which', 'has'): 0.0017
# ('has', 'been'): 0.0029
# ('been', 'under'): 0.0017
# ('under', 'fire'): 0.0017
# ('fire', 'for'): 0.0017
# ('for', 'its'): 0.0016
# ('its', 'practices'): 0.0017
# ('practices', 'in'): 0.0017
# ('the', 'appointment'): 0.0016
# ('appointment', 'of'): 0.0017
# ('of', 'appraisers'): 0.0016
# ('appraisers', ','): 0.0017
# (',', 'guardians'): 0.0016
# ('guardians', 'and'): 0.0017
# ('and', 'administrators'): 0.0016
# ('administrators', 'and'): 0.0017
# ('the', 'awarding'): 0.0016
# ('awarding', 'of'): 0.0017
# ('of', 'fees'): 0.0016
# ('fees', 'and'): 0.0017
# ('and', 'compensation'): 0.0016
# ('compensation', '.'): 0.0017
# ('<s>', 'wards'): 0.0016
# ('wards', 'protected'): 0.0017
# ('protected', 'the'): 0.0017
# ('it', 'found'): 0.0016
# ('found', 'the'): 0.0017
# ('the', 'court'): 0.0019
# ('court', '``'): 0.0017
# ('has', 'incorporated'): 0.0017
# ('incorporated', 'into'): 0.0017
# ('into', 'its'): 0.0017
# ('its', 'operating'): 0.0017
# ('operating', 'procedures'): 0.0017
# ('procedures', 'the'): 0.0017
# ('the', 'recommendations'): 0.0016
# ('recommendations', '``'): 0.0017
# ('``', 'of'): 0.0016
# ('of', 'two'): 0.0020
# ('two', 'previous'): 0.0017
# ('previous', 'grand'): 0.0017
# ('grand', 'juries'): 0.0017
# ('juries', ','): 0.0017
# ('atlanta', 'bar'): 0.0017
# ('bar', 'association'): 0.0017
# ('association', 'and'): 0.0017
# ('and', 'an'): 0.0016
# ('an', 'interim'): 0.0017
# ('interim', 'citizens'): 0.0017
# ('citizens', 'committee'): 0.0017
# ('committee', '.'): 0.0021
# ('these', 'actions'): 0.0017
# ('actions', 'should'): 0.0017
# ('should', 'serve'): 0.0017
# ('serve', 'to'): 0.0017
# ('to', 'protect'): 0.0016
# ('protect', 'in'): 0.0017
# ('in', 'fact'): 0.0016
# ('fact', 'and'): 0.0017
# ('and', 'in'): 0.0016
# ('in', 'effect'): 0.0016
# ('effect', 'the'): 0.0017
# ('court', "'s"): 0.0017
# ("'s", 'wards'): 0.0016
# ('wards', 'from'): 0.0017
# ('from', 'undue'): 0.0017
# ('undue', 'costs'): 0.0017
# ('costs', 'and'): 0.0017
# ('and', 'its'): 0.0016
# ('its', 'appointed'): 0.0017
# ('appointed', 'and'): 0.0017
# ('and', 'elected'): 0.0016
# ('elected', 'servants'): 0.0017
# ('servants', 'from'): 0.0017
# ('from', 'unmeritorious'): 0.0017
# ('unmeritorious', 'criticisms'): 0.0017
# ('criticisms', '``'): 0.0017
# ('<s>', 'regarding'): 0.0016
# ('regarding', 'atlanta'): 0.0017
# ("'s", 'new'): 0.0016
# ('new', 'multi-million-dollar'): 0.0017
# ('multi-million-dollar', 'airport'): 0.0017
# ('airport', ','): 0.0017
# ('jury', 'recommended'): 0.0021
# ('recommended', '``'): 0.0017
# ('that', 'when'): 0.0016
# ('when', 'the'): 0.0025
# ('the', 'new'): 0.0023
# ('new', 'management'): 0.0017
# ('management', 'takes'): 0.0017
# ('takes', 'charge'): 0.0017
# ('charge', 'jan.'): 0.0017
# ('jan.', '1'): 0.0021
# ('1', 'the'): 0.0017
# ('the', 'airport'): 0.0016
# ('airport', 'be'): 0.0017
# ('be', 'operated'): 0.0016
# ('operated', 'in'): 0.0017
# ('in', 'a'): 0.0024
# ('a', 'manner'): 0.0016
# ('manner', 'that'): 0.0017
# ('that', 'will'): 0.0021
# ('will', 'eliminate'): 0.0017
# ('eliminate', 'political'): 0.0017
# ('political', 'influences'): 0.0017
# ('influences', '``'): 0.0017
# ('jury', 'did'): 0.0016
# ('did', 'not'): 0.0017
# ('not', 'elaborate'): 0.0017
# ('elaborate', ','): 0.0017
# ('but', 'it'): 0.0017
# ('it', 'added'): 0.0016
# ('added', 'that'): 0.0025
# ('that', '``'): 0.0021
# ('``', 'there'): 0.0020
# ('there', 'should'): 0.0017
# ('be', 'periodic'): 0.0016
# ('periodic', 'surveillance'): 0.0017
# ('surveillance', 'of'): 0.0017
# ('the', 'pricing'): 0.0016
# ('pricing', 'practices'): 0.0017
# ('practices', 'of'): 0.0017
# ('the', 'concessionaires'): 0.0016
# ('concessionaires', 'for'): 0.0017
# ('the', 'purpose'): 0.0016
# ('purpose', 'of'): 0.0017
# ('of', 'keeping'): 0.0016
# ('keeping', 'the'): 0.0017
# ('the', 'prices'): 0.0016
# ('prices', 'reasonable'): 0.0017
# ('reasonable', '``'): 0.0017
# ('<s>', 'ask'): 0.0016
# ('ask', 'jail'): 0.0017
# ('jail', 'deputies'): 0.0017
# ('deputies', 'on'): 0.0017
# ('on', 'other'): 0.0017
# ('other', 'matters'): 0.0017
# ('matters', ','): 0.0017
# ('that', ':'): 0.0016
# (':', '('): 0.0017
# ('(', '1'): 0.0017
# ('1', ')'): 0.0017
# (')', 'four'): 0.0017
# ('four', 'additional'): 0.0017
# ('additional', 'deputies'): 0.0017
# ('deputies', 'be'): 0.0017
# ('be', 'employed'): 0.0021
# ('employed', 'at'): 0.0017
# ('county', 'jail'): 0.0017
# ('jail', 'and'): 0.0017
# ('and', '``'): 0.0016
# ('a', 'doctor'): 0.0016
# ('doctor', ','): 0.0017
# (',', 'medical'): 0.0016
# ('medical', 'intern'): 0.0017
# ('intern', 'or'): 0.0017
# ('or', 'extern'): 0.0017
# ('extern', 'be'): 0.0017
# ('employed', 'for'): 0.0017
# ('for', 'night'): 0.0016
# ('night', 'and'): 0.0017
# ('and', 'weekend'): 0.0016
# ('weekend', 'duty'): 0.0017
# ('duty', 'at'): 0.0017
# ('the', 'jail'): 0.0016
# ('jail', '``'): 0.0017
# ('<s>', '('): 0.0016
# ('(', '2'): 0.0017
# ('2', ')'): 0.0017
# (')', 'fulton'): 0.0017
# ('legislators', '``'): 0.0017
# ('``', 'work'): 0.0016
# ('work', 'with'): 0.0017
# ('with', 'city'): 0.0017
# ('city', 'officials'): 0.0017
# ('officials', 'to'): 0.0017
# ('to', 'pass'): 0.0016
# ('pass', 'enabling'): 0.0017
# ('enabling', 'legislation'): 0.0017
# ('legislation', 'that'): 0.0017
# ('will', 'permit'): 0.0017
# ('permit', 'the'): 0.0017
# ('the', 'establishment'): 0.0016
# ('establishment', 'of'): 0.0017
# ('of', 'a'): 0.0020
# ('a', 'fair'): 0.0016
# ('fair', 'and'): 0.0017
# ('and', 'equitable'): 0.0016
# ('equitable', '``'): 0.0017
# ('``', 'pension'): 0.0016
# ('pension', 'plan'): 0.0017
# ('plan', 'for'): 0.0017
# ('for', 'city'): 0.0016
# ('city', 'employes'): 0.0017
# ('employes', '.'): 0.0017
# ('jury', 'praised'): 0.0016
# ('praised', 'the'): 0.0017
# ('the', 'administration'): 0.0016
# ('administration', 'and'): 0.0017
# ('and', 'operation'): 0.0016
# ('operation', 'of'): 0.0017
# ('atlanta', 'police'): 0.0017
# ('police', 'department'): 0.0017
# ('fulton', 'tax'): 0.0017
# ('tax', 'commissioner'): 0.0017
# ('commissioner', "'s"): 0.0017
# ("'s", 'office'): 0.0016
# ('office', ','): 0.0017
# ('the', 'bellwood'): 0.0016
# ('bellwood', 'and'): 0.0017
# ('and', 'alpharetta'): 0.0016
# ('alpharetta', 'prison'): 0.0017
# ('prison', 'farms'): 0.0017
# ('farms', ','): 0.0017
# (',', 'grady'): 0.0016
# ('grady', 'hospital'): 0.0017
# ('hospital', 'and'): 0.0017
# ('fulton', 'health'): 0.0017
# ('health', 'department'): 0.0017
# ('department', '.'): 0.0017
# ('<s>', 'mayor'): 0.0016
# ('mayor', 'william'): 0.0017
# ('william', 'b.'): 0.0017
# ('b.', 'hartsfield'): 0.0017
# ('hartsfield', 'filed'): 0.0017
# ('filed', 'suit'): 0.0017
# ('suit', 'for'): 0.0017
# ('for', 'divorce'): 0.0016
# ('divorce', 'from'): 0.0017
# ('from', 'his'): 0.0017
# ('his', 'wife'): 0.0021
# ('wife', ','): 0.0017
# (',', 'pearl'): 0.0016
# ('pearl', 'williams'): 0.0017
# ('williams', 'hartsfield'): 0.0017
# ('hartsfield', ','): 0.0017
# (',', 'in'): 0.0020
# ('in', 'fulton'): 0.0016
# ('court', 'friday'): 0.0017
# ('friday', '.'): 0.0017
# ('<s>', 'his'): 0.0020
# ('his', 'petition'): 0.0017
# ('petition', 'charged'): 0.0017
# ('charged', 'mental'): 0.0017
# ('mental', 'cruelty'): 0.0017
# ('cruelty', '.'): 0.0017
# ('the', 'couple'): 0.0019
# ('couple', 'was'): 0.0017
# ('was', 'married'): 0.0016
# ('married', 'aug.'): 0.0017
# ('aug.', '2'): 0.0017
# ('2', ','): 0.0017
# (',', '1913'): 0.0016
# ('1913', '.'): 0.0017
# ('<s>', 'they'): 0.0016
# ('they', 'have'): 0.0017
# ('have', 'a'): 0.0021
# ('a', 'son'): 0.0016
# ('son', ','): 0.0017
# (',', 'william'): 0.0016
# ('william', 'berry'): 0.0017
# ('berry', 'jr.'): 0.0017
# ('jr.', ','): 0.0021
# (',', 'and'): 0.0032
# ('and', 'a'): 0.0016
# ('a', 'daughter'): 0.0016
# ('daughter', ','): 0.0017
# (',', 'mrs.'): 0.0016
# ('mrs.', 'j.'): 0.0017
# ('j.', 'm.'): 0.0017
# ('m.', 'cheshire'): 0.0017
# ('cheshire', 'of'): 0.0017
# ('of', 'griffin'): 0.0016
# ('griffin', '.'): 0.0021
# ('<s>', 'attorneys'): 0.0016
# ('attorneys', 'for'): 0.0017
# ('the', 'mayor'): 0.0027
# ('mayor', 'said'): 0.0017
# ('said', 'that'): 0.0021
# ('an', 'amicable'): 0.0017
# ('amicable', 'property'): 0.0017
# ('property', 'settlement'): 0.0017
# ('settlement', 'has'): 0.0017
# ('been', 'agreed'): 0.0017
# ('agreed', 'upon'): 0.0017
# ('upon', '.'): 0.0017
# ('the', 'petition'): 0.0023
# ('petition', 'listed'): 0.0017
# ('listed', 'the'): 0.0017
# ('mayor', "'s"): 0.0025
# ("'s", 'occupation'): 0.0016
# ('occupation', 'as'): 0.0017
# ('as', '``'): 0.0017
# ('``', 'attorney'): 0.0016
# ('attorney', '``'): 0.0017
# ('``', 'and'): 0.0016
# ('and', 'his'): 0.0016
# ('his', 'age'): 0.0017
# ('age', 'as'): 0.0021
# ('as', '71'): 0.0017
# ('71', '.'): 0.0017
# ('it', 'listed'): 0.0016
# ('listed', 'his'): 0.0017
# ('wife', "'s"): 0.0017
# ("'s", 'age'): 0.0016
# ('as', '74'): 0.0017
# ('74', 'and'): 0.0017
# ('and', 'place'): 0.0016
# ('place', 'of'): 0.0017
# ('of', 'birth'): 0.0016
# ('birth', 'as'): 0.0017
# ('as', 'opelika'): 0.0017
# ('opelika', ','): 0.0017
# (',', 'ala.'): 0.0016
# ('ala.', '.'): 0.0017
# ('petition', 'said'): 0.0017
# ('couple', 'has'): 0.0017
# ('has', 'not'): 0.0021
# ('not', 'lived'): 0.0017
# ('lived', 'together'): 0.0017
# ('together', 'as'): 0.0017
# ('as', 'man'): 0.0017
# ('man', 'and'): 0.0017
# ('and', 'wife'): 0.0016
# ('wife', 'for'): 0.0017
# ('for', 'more'): 0.0016
# ('more', 'than'): 0.0021
# ('than', 'a'): 0.0017
# ('a', 'year'): 0.0016
# ('year', '.'): 0.0017
# ('the', 'hartsfield'): 0.0016
# ('hartsfield', 'home'): 0.0017
# ('home', 'is'): 0.0017
# ('is', 'at'): 0.0017
# ('at', '637'): 0.0017
# ('637', 'e.'): 0.0017
# ('e.', 'pelham'): 0.0017
# ('pelham', 'rd'): 0.0017
# ('rd', '.'): 0.0017
# ('<s>', 'aj'): 0.0016
# ('aj', '.'): 0.0017
# ('<s>', 'henry'): 0.0016
# ('henry', 'l.'): 0.0017
# ('l.', 'bowden'): 0.0017
# ('bowden', 'was'): 0.0017
# ('was', 'listed'): 0.0016
# ('listed', 'on'): 0.0017
# ('petition', 'as'): 0.0017
# ('as', 'the'): 0.0017
# ("'s", 'attorney'): 0.0016
# ('attorney', '.'): 0.0017
# ('<s>', 'hartsfield'): 0.0016
# ('hartsfield', 'has'): 0.0017
# ('been', 'mayor'): 0.0017
# ('mayor', 'of'): 0.0017
# ('atlanta', ','): 0.0017
# (',', 'with'): 0.0016
# ('with', 'exception'): 0.0017
# ('of', 'one'): 0.0016
# ('one', 'brief'): 0.0017
# ('brief', 'interlude'): 0.0017
# ('interlude', ','): 0.0017
# (',', 'since'): 0.0016
# ('since', '1937'): 0.0017
# ('1937', '.'): 0.0017
# ('his', 'political'): 0.0017
# ('political', 'career'): 0.0017
# ('career', 'goes'): 0.0017
# ('goes', 'back'): 0.0017
# ('back', 'to'): 0.0017
# ('to', 'his'): 0.0016
# ('his', 'election'): 0.0017
# ('election', 'to'): 0.0017
# ('to', 'city'): 0.0016
# ('city', 'council'): 0.0017
# ('council', 'in'): 0.0017
# ('in', '1923'): 0.0016
# ('1923', '.'): 0.0017
# ("'s", 'present'): 0.0016
# ('present', 'term'): 0.0017
# ('term', 'of'): 0.0017
# ('of', 'office'): 0.0016
# ('office', 'expires'): 0.0017
# ('expires', 'jan.'): 0.0017
# ('1', '.'): 0.0017
# ('<s>', 'he'): 0.0020
# ('he', 'will'): 0.0021
# ('will', 'be'): 0.0029
# ('be', 'succeeded'): 0.0021
# ('succeeded', 'by'): 0.0021
# ('by', 'ivan'): 0.0017
# (',', 'who'): 0.0028
# ('who', 'became'): 0.0017
# ('became', 'a'): 0.0017
# ('a', 'candidate'): 0.0028
# ('candidate', 'in'): 0.0021
# ('the', 'sept.'): 0.0016
# ('sept.', '13'): 0.0017
# ('13', 'primary'): 0.0017
# ('primary', 'after'): 0.0017
# ('after', 'mayor'): 0.0017
# ('mayor', 'hartsfield'): 0.0017
# ('hartsfield', 'announced'): 0.0017
# ('announced', 'that'): 0.0017
# ('that', 'he'): 0.0016
# ('he', 'would'): 0.0017
# ('would', 'not'): 0.0017
# ('not', 'run'): 0.0017
# ('run', 'for'): 0.0017
# ('for', 'reelection'): 0.0016
# ('reelection', '.'): 0.0017
# ('<s>', 'georgia'): 0.0016
# ('georgia', 'republicans'): 0.0017
# ('republicans', 'are'): 0.0017
# ('are', 'getting'): 0.0017
# ('getting', 'strong'): 0.0017
# ('strong', 'encouragement'): 0.0017
# ('encouragement', 'to'): 0.0017
# ('to', 'enter'): 0.0020
# ('enter', 'a'): 0.0021
# ('the', '1962'): 0.0016
# ('1962', 'governor'): 0.0017
# ('governor', "'s"): 0.0017
# ("'s", 'race'): 0.0016
# ('race', ','): 0.0025
# (',', 'a'): 0.0024
# ('a', 'top'): 0.0016
# ('top', 'official'): 0.0017
# ('official', 'said'): 0.0017
# ('said', 'wednesday'): 0.0016
# ('wednesday', '.'): 0.0017
# ('<s>', 'robert'): 0.0016
# ('robert', 'snodgrass'): 0.0017
# ('snodgrass', ','): 0.0017
# (',', 'state'): 0.0020
# ('state', 'gop'): 0.0017
# ('gop', 'chairman'): 0.0017
# ('chairman', ','): 0.0017
# (',', 'said'): 0.0020
# ('said', 'a'): 0.0016
# ('a', 'meeting'): 0.0016
# ('meeting', 'held'): 0.0017
# ('held', 'tuesday'): 0.0017
# ('tuesday', 'night'): 0.0017
# ('night', 'in'): 0.0017
# ('in', 'blue'): 0.0016
# ('blue', 'ridge'): 0.0021
# ('ridge', 'brought'): 0.0017
# ('brought', 'enthusiastic'): 0.0017
# ('enthusiastic', 'responses'): 0.0017
# ('responses', 'from'): 0.0017
# ('from', 'the'): 0.0017
# ('the', 'audience'): 0.0019
# ('audience', '.'): 0.0017
# ('<s>', 'state'): 0.0016
# ('state', 'party'): 0.0017
# ('party', 'chairman'): 0.0017
# ('chairman', 'james'): 0.0017
# ('james', 'w.'): 0.0017
# ('w.', 'dorsey'): 0.0017
# ('dorsey', 'added'): 0.0017
# ('that', 'enthusiasm'): 0.0016
# ('enthusiasm', 'was'): 0.0017
# ('was', 'picking'): 0.0016
# ('picking', 'up'): 0.0017
# ('up', 'for'): 0.0017
# ('for', 'a'): 0.0021
# ('a', 'state'): 0.0020
# ('state', 'rally'): 0.0017
# ('rally', 'to'): 0.0017
# ('to', 'be'): 0.0016
# ('be', 'held'): 0.0016
# ('held', 'sept.'): 0.0017
# ('sept.', '8'): 0.0017
# ('8', 'in'): 0.0017
# ('in', 'savannah'): 0.0016
# ('savannah', 'at'): 0.0017
# ('at', 'which'): 0.0017
# ('which', 'newly'): 0.0017
# ('newly', 'elected'): 0.0017
# ('elected', 'texas'): 0.0017
# ('texas', 'sen.'): 0.0017
# ('sen.', 'john'): 0.0017
# ('john', 'tower'): 0.0017
# ('tower', 'will'): 0.0017
# ('be', 'the'): 0.0016
# ('the', 'featured'): 0.0016
# ('featured', 'speaker'): 0.0017
# ('speaker', '.'): 0.0017
# ('<s>', 'in'): 0.0016
# ('the', 'blue'): 0.0016
# ('ridge', 'meeting'): 0.0017
# ('meeting', ','): 0.0017
# ('audience', 'was'): 0.0017
# ('was', 'warned'): 0.0016
# ('warned', 'that'): 0.0017
# ('that', 'entering'): 0.0016
# ('entering', 'a'): 0.0017
# ('candidate', 'for'): 0.0017
# ('for', 'governor'): 0.0021
# ('governor', 'would'): 0.0017
# ('would', 'force'): 0.0017
# ('force', 'it'): 0.0017
# ('it', 'to'): 0.0016
# ('to', 'take'): 0.0016
# ('take', 'petitions'): 0.0017
# ('petitions', 'out'): 0.0017
# ('out', 'into'): 0.0017
# ('into', 'voting'): 0.0017
# ('voting', 'precincts'): 0.0017
# ('precincts', 'to'): 0.0017
# ('to', 'obtain'): 0.0016
# ('obtain', 'the'): 0.0017
# ('the', 'signatures'): 0.0016
# ('signatures', 'of'): 0.0017
# ('of', 'registered'): 0.0016
# ('registered', 'voters'): 0.0017
# ('voters', '.'): 0.0017
# ('<s>', 'despite'): 0.0016
# ('despite', 'the'): 0.0021
# ('the', 'warning'): 0.0016
# ('warning', ','): 0.0017
# (',', 'there'): 0.0020
# ('there', 'was'): 0.0029
# ('was', 'a'): 0.0016
# ('a', 'unanimous'): 0.0016
# ('unanimous', 'vote'): 0.0017
# ('vote', 'to'): 0.0017
# ('candidate', ','): 0.0017
# (',', 'according'): 0.0016
# ('according', 'to'): 0.0017
# ('to', 'republicans'): 0.0016
# ('republicans', 'who'): 0.0017
# ('who', 'attended'): 0.0017
# ('attended', '.'): 0.0017
# ('<s>', 'when'): 0.0020
# ('the', 'crowd'): 0.0016
# ('crowd', 'was'): 0.0017
# ('was', 'asked'): 0.0016
# ('asked', 'whether'): 0.0017
# ('whether', 'it'): 0.0017
# ('it', 'wanted'): 0.0016
# ('wanted', 'to'): 0.0017
# ('to', 'wait'): 0.0016
# ('wait', 'one'): 0.0017
# ('one', 'more'): 0.0017
# ('more', 'term'): 0.0017
# ('term', 'to'): 0.0017
# ('to', 'make'): 0.0024
# ('make', 'the'): 0.0025
# ('the', 'race'): 0.0016
# (',', 'it'): 0.0020
# ('it', 'voted'): 0.0016
# ('voted', 'no'): 0.0017
# ('no', '--'): 0.0017
# ('--', 'and'): 0.0017
# ('and', 'there'): 0.0016
# ('there', 'were'): 0.0017
# ('were', 'no'): 0.0017
# ('no', 'dissents'): 0.0017
# ('dissents', '.'): 0.0017
# ('the', 'largest'): 0.0016
# ('largest', 'hurdle'): 0.0017
# ('hurdle', 'the'): 0.0017
# ('the', 'republicans'): 0.0023
# ('republicans', 'would'): 0.0017
# ('would', 'have'): 0.0021
# ('have', 'to'): 0.0021
# ('to', 'face'): 0.0016
# ('face', 'is'): 0.0017
# ('is', 'a'): 0.0021
# ('state', 'law'): 0.0017
# ('law', 'which'): 0.0017
# ('which', 'says'): 0.0017
# ('says', 'that'): 0.0021
# ('that', 'before'): 0.0016
# ('before', 'making'): 0.0017
# ('making', 'a'): 0.0017
# ('a', 'first'): 0.0016
# ('first', 'race'): 0.0017
# (',', 'one'): 0.0016
# ('two', 'alternative'): 0.0017
# ('alternative', 'courses'): 0.0017
# ('courses', 'must'): 0.0017
# ('must', 'be'): 0.0017
# ('be', 'taken'): 0.0016
# ('taken', ':'): 0.0017
# (':', '1'): 0.0017
# ('1', 'five'): 0.0017
# ('five', 'per'): 0.0017
# ('per', 'cent'): 0.0017
# ('cent', 'of'): 0.0017
# ('the', 'voters'): 0.0016
# ('voters', 'in'): 0.0017
# ('in', 'each'): 0.0016
# ('each', 'county'): 0.0017
# ('county', 'must'): 0.0017
# ('must', 'sign'): 0.0017
# ('sign', 'petitions'): 0.0017
# ('petitions', 'requesting'): 0.0017
# ('requesting', 'that'): 0.0017
# ('republicans', 'be'): 0.0017
# ('be', 'allowed'): 0.0016
# ('allowed', 'to'): 0.0017
# ('place', 'names'): 0.0017
# ('names', 'of'): 0.0017
# ('of', 'candidates'): 0.0016
# ('candidates', 'on'): 0.0017
# ('the', 'general'): 0.0016
# ('general', 'election'): 0.0017
# ('election', 'ballot'): 0.0017
# ('ballot', ','): 0.0017
# (',', 'or'): 0.0016
# ('or', '2'): 0.0017
# ('2', 'the'): 0.0017
# ('republicans', 'must'): 0.0017
# ('must', 'hold'): 0.0017
# ('hold', 'a'): 0.0017
# ('a', 'primary'): 0.0016
# ('primary', 'under'): 0.0017
# ('under', 'the'): 0.0017
# ('the', 'county'): 0.0019
# ('county', 'unit'): 0.0017
# ('unit', 'system'): 0.0017
# ('system', '--'): 0.0017
# ('--', 'a'): 0.0017
# ('a', 'system'): 0.0016
# ('system', 'which'): 0.0017
# ('the', 'party'): 0.0016
# ('party', 'opposes'): 0.0017
# ('opposes', 'in'): 0.0017
# ('in', 'its'): 0.0016
# ('its', 'platform'): 0.0017
# ('platform', '.'): 0.0017
# ('<s>', 'sam'): 0.0016
# ('sam', 'caldwell'): 0.0017
# ('caldwell', ','): 0.0017
# ('state', 'highway'): 0.0021
# ('highway', 'department'): 0.0029
# ('department', 'public'): 0.0017
# ('public', 'relations'): 0.0017
# ('relations', 'director'): 0.0017
# ('director', ','): 0.0017
# (',', 'resigned'): 0.0016
# ('resigned', 'tuesday'): 0.0017
# ('tuesday', 'to'): 0.0017
# ('to', 'work'): 0.0016
# ('work', 'for'): 0.0017
# ('for', 'lt.'): 0.0016
# ('lt.', 'gov'): 0.0017
# ('gov', '.'): 0.0029
# ('<s>', 'garland'): 0.0016
# ('garland', 'byrd'): 0.0017
# ('byrd', "'s"): 0.0017
# ("'s", 'campaign'): 0.0016
# ('campaign', '.'): 0.0017
# ('<s>', 'caldwell'): 0.0016
# ('caldwell', "'s"): 0.0017
# ("'s", 'resignation'): 0.0016
# ('resignation', 'had'): 0.0017
# ('been', 'expected'): 0.0017
# ('expected', 'for'): 0.0017
# ('for', 'some'): 0.0016
# ('some', 'time'): 0.0017
# ('time', '.'): 0.0017
# ('by', 'rob'): 0.0017
# ('rob', 'ledford'): 0.0017
# ('ledford', 'of'): 0.0017
# ('of', 'gainesville'): 0.0016
# ('gainesville', ','): 0.0017
# ('who', 'has'): 0.0017
# ('been', 'an'): 0.0017
# ('an', 'assistant'): 0.0017
# ('assistant', 'more'): 0.0017
# ('than', 'three'): 0.0017
# ('three', 'years'): 0.0017
# ('years', '.'): 0.0017
# ('the', 'gubernatorial'): 0.0016
# ('gubernatorial', 'campaign'): 0.0017
# ('campaign', 'starts'): 0.0017
# ('starts', ','): 0.0017
# (',', 'caldwell'): 0.0016
# ('caldwell', 'is'): 0.0017
# ('is', 'expected'): 0.0025
# ('expected', 'to'): 0.0025
# ('to', 'become'): 0.0016
# ('become', 'a'): 0.0017
# ('a', 'campaign'): 0.0016
# ('campaign', 'coordinator'): 0.0017
# ('coordinator', 'for'): 0.0017
# ('for', 'byrd'): 0.0016
# ('byrd', '.'): 0.0017
# ('the', 'georgia'): 0.0019
# ('georgia', 'legislature'): 0.0017
# ('legislature', 'will'): 0.0017
# ('will', 'wind'): 0.0017
# ('wind', 'up'): 0.0017
# ('up', 'its'): 0.0017
# ('its', '1961'): 0.0017
# ('1961', 'session'): 0.0017
# ('session', 'monday'): 0.0017
# ('monday', 'and'): 0.0017
# ('and', 'head'): 0.0016
# ('head', 'for'): 0.0017
# ('for', 'home'): 0.0016
# ('home', '--'): 0.0017
# ('--', 'where'): 0.0017
# ('where', 'some'): 0.0017
# ('some', 'of'): 0.0021
# ('the', 'highway'): 0.0019
# ('highway', 'bond'): 0.0021
# ('bond', 'money'): 0.0017
# ('money', 'it'): 0.0017
# ('it', 'approved'): 0.0016
# ('approved', 'will'): 0.0017
# ('will', 'follow'): 0.0017
# ('follow', 'shortly'): 0.0017
# ('shortly', '.'): 0.0017
# ('<s>', 'before'): 0.0016
# ('before', 'adjournment'): 0.0017
# ('adjournment', 'monday'): 0.0017
# ('monday', 'afternoon'): 0.0017
# ('afternoon', ','): 0.0017
# ('the', 'senate'): 0.0019
# ('senate', 'is'): 0.0017
# ('to', 'approve'): 0.0016
# ('approve', 'a'): 0.0017
# ('a', 'study'): 0.0016
# ('study', 'of'): 0.0017
# ('of', 'legislators'): 0.0016
# ('legislators', 'allotted'): 0.0017
# ('allotted', 'to'): 0.0017
# ('to', 'rural'): 0.0016
# ('rural', 'and'): 0.0017
# ('and', 'urban'): 0.0016
# ('urban', 'areas'): 0.0017
# ('areas', 'to'): 0.0017
# ('to', 'determine'): 0.0016
# ('determine', 'what'): 0.0017
# ('what', 'adjustments'): 0.0017
# ('adjustments', 'should'): 0.0017
# ('be', 'made'): 0.0016
# ('made', '.'): 0.0017
# ('<s>', 'gov'): 0.0016
# ('<s>', 'vandiver'): 0.0024
# ('vandiver', 'is'): 0.0017
# ('the', 'traditional'): 0.0016
# ('traditional', 'visit'): 0.0017
# ('visit', 'to'): 0.0017
# ('to', 'both'): 0.0016
# ('both', 'chambers'): 0.0017
# ('chambers', 'as'): 0.0017
# ('as', 'they'): 0.0017
# ('they', 'work'): 0.0017
# ('work', 'toward'): 0.0017
# ('toward', 'adjournment'): 0.0017
# ('adjournment', '.'): 0.0017
# ('vandiver', 'likely'): 0.0017
# ('likely', 'will'): 0.0017
# ('will', 'mention'): 0.0017
# ('mention', 'the'): 0.0017
# ('the', '$'): 0.0016
# ('$', '100'): 0.0017
# ('100', 'million'): 0.0017
# ('million', 'highway'): 0.0017
# ('bond', 'issue'): 0.0021
# ('issue', 'approved'): 0.0017
# ('approved', 'earlier'): 0.0017
# ('earlier', 'in'): 0.0017
# ('the', 'session'): 0.0016
# ('session', 'as'): 0.0017
# ('as', 'his'): 0.0017
# ('his', 'first'): 0.0017
# ('first', 'priority'): 0.0017
# ('priority', 'item'): 0.0017
# ('item', '.'): 0.0017
# ('<s>', 'construction'): 0.0016
# ('construction', 'bonds'): 0.0017
# ('bonds', 'meanwhile'): 0.0017
# ('meanwhile', ','): 0.0017
# ('it', 'was'): 0.0021
# ('was', 'learned'): 0.0016
# ('learned', 'the'): 0.0017
# ('department', 'is'): 0.0017
# ('is', 'very'): 0.0017
# ('very', 'near'): 0.0017
# ('near', 'being'): 0.0017
# ('being', 'ready'): 0.0017
# ('ready', 'to'): 0.0017
# ('to', 'issue'): 0.0024
# ('issue', 'the'): 0.0021
# ('the', 'first'): 0.0016
# ('first', '$'): 0.0017
# ('$', '30'): 0.0017
# ('30', 'million'): 0.0017
# ('million', 'worth'): 0.0025
# ('worth', 'of'): 0.0025
# ('of', 'highway'): 0.0016
# ('highway', 'reconstruction'): 0.0017
# ('reconstruction', 'bonds'): 0.0017
# ('bonds', '.'): 0.0021
# ('the', 'bond'): 0.0016
# ('issue', 'will'): 0.0017
# ('will', 'go'): 0.0017
# ('go', 'to'): 0.0017
# ('state', 'courts'): 0.0017
# ('courts', 'for'): 0.0017
# ('a', 'friendly'): 0.0016
# ('friendly', 'test'): 0.0017
# ('test', 'suit'): 0.0017
# ('suit', 'to'): 0.0017
# ('to', 'test'): 0.0016
# ('test', 'the'): 0.0017
# ('the', 'validity'): 0.0016
# ('validity', 'of'): 0.0017
# ('the', 'act'): 0.0016
# ('act', ','): 0.0017
# ('and', 'then'): 0.0016
# ('then', 'the'): 0.0017
# ('the', 'sales'): 0.0016
# ('sales', 'will'): 0.0017
# ('will', 'begin'): 0.0017
# ('begin', 'and'): 0.0017
# ('and', 'contracts'): 0.0016
# ('contracts', 'let'): 0.0017
# ('let', 'for'): 0.0017
# ('for', 'repair'): 0.0016
# ('repair', 'work'): 0.0017
# ('work', 'on'): 0.0017
# ('on', 'some'): 0.0017
# ("'s", 'most'): 0.0016
# ('most', 'heavily'): 0.0017
# ('heavily', 'traveled'): 0.0017
# ('traveled', 'highways'): 0.0017
# ('highways', '.'): 0.0017
# ('<s>', 'a'): 0.0028
# ('a', 'highway'): 0.0016
# ('department', 'source'): 0.0021
# ('source', 'said'): 0.0017
# ('said', 'there'): 0.0021
# ('there', 'also'): 0.0017
# ('also', 'is'): 0.0017
# ('a', 'plan'): 0.0016
# ('plan', 'there'): 0.0017
# ('there', 'to'): 0.0021
# ('issue', 'some'): 0.0017
# ('some', '$'): 0.0017
# ('$', '3'): 0.0017
# ('3', 'million'): 0.0017
# ('million', 'to'): 0.0017
# ('to', '$'): 0.0016
# ('$', '4'): 0.0017
# ('4', 'million'): 0.0017
# ('of', 'rural'): 0.0016
# ('rural', 'roads'): 0.0029
# ('roads', 'authority'): 0.0021
# ('authority', 'bonds'): 0.0017
# ('bonds', 'for'): 0.0017
# ('for', 'rural'): 0.0016
# ('rural', 'road'): 0.0017
# ('road', 'construction'): 0.0017
# ('construction', 'work'): 0.0017
# ('work', '.'): 0.0017
# ('a', 'revolving'): 0.0020
# ('revolving', 'fund'): 0.0021
# ('fund', 'the'): 0.0017
# ('the', 'department'): 0.0016
# ('department', 'apparently'): 0.0017
# ('apparently', 'intends'): 0.0017
# ('intends', 'to'): 0.0017
# ('the', 'rural'): 0.0016
# ('authority', 'a'): 0.0017
# ('fund', 'under'): 0.0017
# ('under', 'which'): 0.0017
# ('which', 'new'): 0.0017
# ('new', 'bonds'): 0.0017
# ('bonds', 'would'): 0.0017
# ('would', 'be'): 0.0025
# ('be', 'issued'): 0.0016
# ('issued', 'every'): 0.0017
# ('every', 'time'): 0.0017
# ('time', 'a'): 0.0017
# ('a', 'portion'): 0.0016
# ('the', 'old'): 0.0016
# ('old', 'ones'): 0.0017
# ('ones', 'are'): 0.0017
# ('are', 'paid'): 0.0017
# ('paid', 'off'): 0.0017
# ('off', 'by'): 0.0017
# ('by', 'tax'): 0.0017
# ('tax', 'authorities'): 0.0017
# ('authorities', '.'): 0.0017
# ('vandiver', 'opened'): 0.0017
# ('opened', 'his'): 0.0017
# ('his', 'race'): 0.0017
# ('race', 'for'): 0.0017
# ('governor', 'in'): 0.0017
# ('in', '1958'): 0.0016
# ('1958', 'with'): 0.0017
# ('with', 'a'): 0.0021
# ('a', 'battle'): 0.0016
# ('battle', 'in'): 0.0017
# ('the', 'legislature'): 0.0016
# ('legislature', 'against'): 0.0017
# ('against', 'the'): 0.0017
# ('the', 'issuance'): 0.0016
# ('issuance', 'of'): 0.0017
# ('of', '$'): 0.0016
# ('$', '50'): 0.0017
# ('50', 'million'): 0.0017
# ('of', 'additional'): 0.0016
# ('additional', 'rural'): 0.0017
# ('roads', 'bonds'): 0.0021
# ('bonds', 'proposed'): 0.0017
# ('proposed', 'by'): 0.0017
# ('by', 'then'): 0.0017
# ('then', 'gov'): 0.0017
# ('<s>', 'marvin'): 0.0016
# ('marvin', 'griffin'): 0.0017
# ('source', 'told'): 0.0017
# ('told', 'the'): 0.0017
# ('the', 'constitution'): 0.0016
# ('constitution', ','): 0.0017
# (',', 'however'): 0.0020
# (',', 'that'): 0.0016
# ('that', 'vandiver'): 0.0016
# ('vandiver', 'has'): 0.0017
# ('not', 'been'): 0.0017
# ('been', 'consulted'): 0.0017
# ('consulted', 'yet'): 0.0017
# ('yet', 'about'): 0.0017
# ('about', 'the'): 0.0017
# ('the', 'plans'): 0.0016
# ('plans', 'to'): 0.0017
# ('new', 'rural'): 0.0017
# ('<s>', 'schley'): 0.0016
# ('schley', 'county'): 0.0017
# ('county', 'rep.'): 0.0017
# ('rep.', 'b.'): 0.0017
# ('b.', 'd.'): 0.0017
# ('d.', 'pelham'): 0.0017
# ('pelham', 'will'): 0.0017
# ('will', 'offer'): 0.0017
# ('offer', 'a'): 0.0017
# ('a', 'resolution'): 0.0020
# ('resolution', 'monday'): 0.0017
# ('monday', 'in'): 0.0017
# ('the', 'house'): 0.0027
# ('house', 'to'): 0.0017
# ('to', 'rescind'): 0.0020
# ('rescind', 'the'): 0.0021
# ('the', 'body'): 0.0016
# ('body', "'s"): 0.0017
# ("'s", 'action'): 0.0016
# ('action', 'of'): 0.0017
# ('of', 'friday'): 0.0016
# ('friday', 'in'): 0.0017
# ('in', 'voting'): 0.0016
# ('voting', 'itself'): 0.0017
# ('itself', 'a'): 0.0017
# ('a', '$'): 0.0016
# ('$', '10'): 0.0017
# ('10', 'per'): 0.0017
# ('per', 'day'): 0.0017
# ('day', 'increase'): 0.0017
# ('increase', 'in'): 0.0021
# ('in', 'expense'): 0.0016
# ('expense', 'allowances'): 0.0017
# ('allowances', '.'): 0.0017
# ('<s>', 'pelham'): 0.0020
# ('pelham', 'said'): 0.0021
# ('said', 'sunday'): 0.0016
# ('sunday', 'night'): 0.0021
# ('night', 'there'): 0.0017
# ('was', 'research'): 0.0016
# ('research', 'being'): 0.0017
# ('being', 'done'): 0.0017
# ('done', 'on'): 0.0017
# ('on', 'whether'): 0.0017
# ('whether', 'the'): 0.0017
# ('the', '``'): 0.0019
# ('``', 'quickie'): 0.0016
# ('quickie', '``'): 0.0017
# ('``', 'vote'): 0.0016
# ('vote', 'on'): 0.0021
# ('the', 'increase'): 0.0016
# ('increase', 'can'): 0.0017
# ('can', 'be'): 0.0017
# ('be', 'repealed'): 0.0016
# ('repealed', 'outright'): 0.0017
# ('outright', 'or'): 0.0017
# ('or', 'whether'): 0.0017
# ('whether', 'notice'): 0.0017
# ('notice', 'would'): 0.0017
# ('to', 'first'): 0.0016
# ('first', 'be'): 0.0017
# ('be', 'given'): 0.0016
# ('given', 'that'): 0.0017
# ('that', 'reconsideration'): 0.0016
# ('reconsideration', 'of'): 0.0017
# ('the', 'action'): 0.0019
# ('action', 'would'): 0.0017
# ('be', 'sought'): 0.0016
# ('sought', '.'): 0.0017
# ('<s>', 'while'): 0.0016
# ('while', 'emphasizing'): 0.0017
# ('emphasizing', 'that'): 0.0017
# ('that', 'technical'): 0.0016
# ('technical', 'details'): 0.0017
# ('details', 'were'): 0.0017
# ('were', 'not'): 0.0017
# ('not', 'fully'): 0.0017
# ('fully', 'worked'): 0.0017
# ('worked', 'out'): 0.0017
# ('out', ','): 0.0017
# (',', 'pelham'): 0.0016
# ('said', 'his'): 0.0016
# ('his', 'resolution'): 0.0017
# ('resolution', 'would'): 0.0017
# ('would', 'seek'): 0.0017
# ('seek', 'to'): 0.0017
# ('to', 'set'): 0.0016
# ('set', 'aside'): 0.0017
# ('aside', 'the'): 0.0017
# ('the', 'privilege'): 0.0016
# ('privilege', 'resolution'): 0.0021
# ('resolution', 'which'): 0.0017
# ('house', 'voted'): 0.0017
# ('voted', 'through'): 0.0017
# ('through', '87-31'): 0.0017
# ('87-31', '.'): 0.0017
# ('a', 'similar'): 0.0016
# ('similar', 'resolution'): 0.0017
# ('resolution', 'passed'): 0.0017
# ('passed', 'in'): 0.0017
# ('senate', 'by'): 0.0017
# ('by', 'a'): 0.0017
# ('a', 'of'): 0.0016
# ('of', '29-5'): 0.0016
# ('29-5', '.'): 0.0017
# ('<s>', 'as'): 0.0016
# ('as', 'of'): 0.0017
# ('of', 'sunday'): 0.0016
# ('night', ','): 0.0017
# ('was', 'no'): 0.0016
# ('no', 'word'): 0.0017
# ('word', 'of'): 0.0017
# ('resolution', 'being'): 0.0017
# ('being', 'offered'): 0.0017
# ('offered', 'there'): 0.0017
# ('action', '.'): 0.0017
# ('pelham', 'pointed'): 0.0017
# ('pointed', 'out'): 0.0017
# ('out', 'that'): 0.0017
# ('that', 'georgia'): 0.0016
# ('georgia', 'voters'): 0.0017
# ('voters', 'last'): 0.0017
# ('last', 'november'): 0.0017
# ('november', 'rejected'): 0.0017
# ('rejected', 'a'): 0.0017
# ('a', 'constitutional'): 0.0016
# ('constitutional', 'amendment'): 0.0017
# ('amendment', 'to'): 0.0017
# ('to', 'allow'): 0.0016
# ('allow', 'legislators'): 0.0017
# ('legislators', 'to'): 0.0017
# ('to', 'vote'): 0.0016
# ('on', 'pay'): 0.0017
# ('pay', 'raises'): 0.0021
# ('raises', 'for'): 0.0017
# ('for', 'future'): 0.0016
# ('future', 'legislature'): 0.0017
# ('legislature', 'sessions'): 0.0017
# ('sessions', '.'): 0.0017
# ('a', 'veteran'): 0.0020
# ('veteran', 'jackson'): 0.0017
# ('jackson', 'county'): 0.0017
# ('county', 'legislator'): 0.0017
# ('legislator', 'will'): 0.0017
# ('will', 'ask'): 0.0017
# ('ask', 'the'): 0.0017
# ('georgia', 'house'): 0.0017
# ('house', 'monday'): 0.0017
# ('monday', 'to'): 0.0017
# ('to', 'back'): 0.0016
# ('back', 'federal'): 0.0017
# ('federal', 'aid'): 0.0017
# ('aid', 'to'): 0.0017
# ('to', 'education'): 0.0016
# ('education', ','): 0.0021
# (',', 'something'): 0.0016
# ('something', 'it'): 0.0017
# ('it', 'has'): 0.0016
# ('has', 'consistently'): 0.0017
# ('consistently', 'opposed'): 0.0017
# ('opposed', 'in'): 0.0017
# ('the', 'past'): 0.0016
# ('past', '.'): 0.0017
# ('<s>', 'rep.'): 0.0016
# ('rep.', 'mac'): 0.0017
# ('mac', 'barber'): 0.0017
# ('barber', 'of'): 0.0017
# ('of', 'commerce'): 0.0016
# ('commerce', 'is'): 0.0017
# ('is', 'asking'): 0.0017
# ('asking', 'the'): 0.0017
# ('house', 'in'): 0.0017
# ('a', 'privilege'): 0.0016
# ('resolution', 'to'): 0.0017
# ('to', '``'): 0.0020
# ('``', 'endorse'): 0.0016
# ('endorse', 'increased'): 0.0017
# ('increased', 'federal'): 0.0017
# ('federal', 'support'): 0.0017
# ('support', 'for'): 0.0017
# ('for', 'public'): 0.0016
# ('public', 'education'): 0.0017
# (',', 'provided'): 0.0016
# ('provided', 'that'): 0.0017
# ('that', 'such'): 0.0016
# ('such', 'funds'): 0.0017
# ('funds', 'be'): 0.0017
# ('be', 'received'): 0.0016
# ('received', 'and'): 0.0017
# ('and', 'expended'): 0.0016
# ('expended', '``'): 0.0017
# ('``', 'as'): 0.0016
# ('as', 'state'): 0.0017
# ('state', 'funds'): 0.0017
# ('funds', '.'): 0.0017
# ('<s>', 'barber'): 0.0016
# ('barber', ','): 0.0017
# ('who', 'is'): 0.0017
# ('is', 'in'): 0.0017
# ('in', 'his'): 0.0016
# ('his', '13th'): 0.0017
# ('13th', 'year'): 0.0017
# ('year', 'as'): 0.0017
# ('a', 'legislator'): 0.0016
# ('legislator', ','): 0.0017
# ('there', '``'): 0.0017
# ('are', 'some'): 0.0017
# ('some', 'members'): 0.0017
# ('members', 'of'): 0.0017
# ('of', 'our'): 0.0016
# ('our', 'congressional'): 0.0017
# ('congressional', 'delegation'): 0.0017
# ('delegation', 'in'): 0.0017
# ('in', 'washington'): 0.0016
# ('washington', 'who'): 0.0017
# ('who', 'would'): 0.0017
# ('would', 'like'): 0.0017
# ('like', 'to'): 0.0017
# ('to', 'see'): 0.0016
# ('see', 'it'): 0.0017
# ('it', '('): 0.0016
# ('(', 'the'): 0.0017
# ('the', 'resolution'): 0.0023
# ('resolution', ')'): 0.0017
# (')', 'passed'): 0.0017
# ('passed', '``'): 0.0017
# ('<s>', 'but'): 0.0016
# ('but', 'he'): 0.0017
# ('he', 'added'): 0.0017
# ('that', 'none'): 0.0016
# ("'s", 'congressmen'): 0.0016
# ('congressmen', 'specifically'): 0.0017
# ('specifically', 'asked'): 0.0017
# ('asked', 'him'): 0.0017
# ('him', 'to'): 0.0017
# ('to', 'offer'): 0.0016
# ('offer', 'the'): 0.0017
# ('resolution', '.'): 0.0017
# ('resolution', ','): 0.0017
# ('which', 'barber'): 0.0017
# ('barber', 'tossed'): 0.0017
# ('tossed', 'into'): 0.0017
# ('into', 'the'): 0.0017
# ('house', 'hopper'): 0.0017
# ('hopper', 'friday'): 0.0017
# ('friday', ','): 0.0017
# (',', 'will'): 0.0016
# ('be', 'formally'): 0.0016
# ('formally', 'read'): 0.0017
# ('read', 'monday'): 0.0017
# ('monday', '.'): 0.0017
# ('it', 'says'): 0.0016
# ('the', 'event'): 0.0016
# ('event', 'congress'): 0.0017
# ('congress', 'does'): 0.0017
# ('does', 'provide'): 0.0017
# ('provide', 'this'): 0.0017
# ('this', 'increase'): 0.0017
# ('in', 'federal'): 0.0016
# ('state', 'board'): 0.0017
# ('board', 'of'): 0.0017
# ('of', 'education'): 0.0016
# ('education', 'should'): 0.0017
# ('be', 'directed'): 0.0016
# ('directed', 'to'): 0.0017
# ('``', 'give'): 0.0016
# ('give', 'priority'): 0.0017
# ('priority', '``'): 0.0017
# ('to', 'teacher'): 0.0016
# ('teacher', 'pay'): 0.0017
# ('raises', '.'): 0.0017
# ('<s>', 'colquitt'): 0.0016
# ('colquitt', '--'): 0.0017
# ('--', 'after'): 0.0017
# ('after', 'a'): 0.0017
# ('a', 'long'): 0.0016
# ('long', ','): 0.0017
# (',', 'hot'): 0.0016
# ('hot', 'controversy'): 0.0017
# ('controversy', ','): 0.0021
# (',', 'miller'): 0.0016
# ('miller', 'county'): 0.0021
# ('county', 'has'): 0.0017
# ('has', 'a'): 0.0017
# ('a', 'new'): 0.0016
# ('new', 'school'): 0.0021
# ('school', 'superintendent'): 0.0025
# ('superintendent', ','): 0.0021
# (',', 'elected'): 0.0016
# ('elected', ','): 0.0017
# (',', 'as'): 0.0016
# ('a', 'policeman'): 0.0016
# ('policeman', 'put'): 0.0017
# ('put', 'it'): 0.0017
# ('it', ','): 0.0016
# ('``', 'coolest'): 0.0016
# ('coolest', 'election'): 0.0017
# ('election', 'i'): 0.0021
# ('i', 'ever'): 0.0021
# ('ever', 'saw'): 0.0021
# ('saw', 'in'): 0.0017
# ('in', 'this'): 0.0016
# ('this', 'county'): 0.0017
# ('county', '``'): 0.0017
# ('superintendent', 'is'): 0.0017
# ('is', 'harry'): 0.0017
# ('harry', 'davis'): 0.0017
# ('davis', ','): 0.0017
# ('veteran', 'agriculture'): 0.0017
# ('agriculture', 'teacher'): 0.0017
# ('teacher', ','): 0.0017
# ('who', 'defeated'): 0.0017
# ('defeated', 'felix'): 0.0017
# ('felix', 'bush'): 0.0017
# ('bush', ','): 0.0021
# ('a', 'school'): 0.0016
# ('school', 'principal'): 0.0017
# ('principal', 'and'): 0.0017
# ('and', 'chairman'): 0.0016
# ('chairman', 'of'): 0.0017
# ('the', 'miller'): 0.0016
# ('county', 'democratic'): 0.0017
# ('democratic', 'executive'): 0.0017
# ('<s>', 'davis'): 0.0016
# ('davis', 'received'): 0.0017
# ('received', '1,119'): 0.0017
# ('1,119', 'votes'): 0.0017
# ('votes', 'in'): 0.0017
# ('in', 'saturday'): 0.0016
# ('saturday', "'s"): 0.0017
# ("'s", 'election'): 0.0016
# ('and', 'bush'): 0.0020
# ('bush', 'got'): 0.0017
# ('got', '402'): 0.0017
# ('402', '.'): 0.0017
# ('<s>', 'ordinary'): 0.0020
# ('ordinary', 'carey'): 0.0017
# ('carey', 'williams'): 0.0017
# ('williams', ','): 0.0017
# (',', 'armed'): 0.0016
# ('armed', 'with'): 0.0017
# ('a', 'pistol'): 0.0016
# ('pistol', ','): 0.0017
# (',', 'stood'): 0.0016
# ('stood', 'by'): 0.0017
# ('by', 'at'): 0.0017
# ('the', 'polls'): 0.0023
# ('polls', 'to'): 0.0017
# ('to', 'insure'): 0.0016
# ('insure', 'order'): 0.0017
# ('order', '.'): 0.0017
# ('this', 'was'): 0.0017
# ('was', 'the'): 0.0016
# ('the', 'coolest'): 0.0016
# ('coolest', ','): 0.0017
# (',', 'calmest'): 0.0016
# ('calmest', 'election'): 0.0017
# ('saw', '``'): 0.0017
# (',', 'colquitt'): 0.0016
# ('colquitt', 'policeman'): 0.0017
# ('policeman', 'tom'): 0.0017
# ('tom', 'williams'): 0.0017
# ('williams', 'said'): 0.0021
# ('``', 'being'): 0.0016
# ('being', 'at'): 0.0021
# ('polls', 'was'): 0.0017
# ('was', 'just'): 0.0016
# ('just', 'like'): 0.0017
# ('like', 'being'): 0.0017
# ('at', 'church'): 0.0017
# ('church', '.'): 0.0017
# ('<s>', 'i'): 0.0016
# ('i', 'did'): 0.0017
# ('did', "n't"): 0.0021
# ("n't", 'smell'): 0.0017
# ('smell', 'a'): 0.0017
# ('a', 'drop'): 0.0016
# ('drop', 'of'): 0.0017
# ('of', 'liquor'): 0.0016
# ('liquor', ','): 0.0017
# ('and', 'we'): 0.0016
# ('we', 'did'): 0.0017
# ("n't", 'have'): 0.0017
# ('a', 'bit'): 0.0020
# ('bit', 'of'): 0.0021
# ('of', 'trouble'): 0.0020
# ('trouble', '``'): 0.0021
# ('the', 'campaign'): 0.0016
# ('campaign', 'leading'): 0.0017
# ('leading', 'to'): 0.0017
# ('was', 'not'): 0.0016
# ('not', 'so'): 0.0017
# ('so', 'quiet'): 0.0017
# ('quiet', ','): 0.0017
# ('however', '.'): 0.0017
# ('was', 'marked'): 0.0016
# ('marked', 'by'): 0.0017
# ('by', 'controversy'): 0.0017
# (',', 'anonymous'): 0.0016
# ('anonymous', 'midnight'): 0.0017
# ('midnight', 'phone'): 0.0017
# ('phone', 'calls'): 0.0017
# ('calls', 'and'): 0.0017
# ('and', 'veiled'): 0.0016
# ('veiled', 'threats'): 0.0017
# ('threats', 'of'): 0.0017
# ('of', 'violence'): 0.0016
# ('violence', '.'): 0.0017
# ('the', 'former'): 0.0016
# ('former', 'county'): 0.0017
# ('county', 'school'): 0.0021
# (',', 'george'): 0.0016
# ('george', 'p.'): 0.0017
# ('p.', 'callan'): 0.0017
# ('callan', ','): 0.0017
# (',', 'shot'): 0.0016
# ('shot', 'himself'): 0.0017
# ('himself', 'to'): 0.0017
# ('to', 'death'): 0.0016
# ('death', 'march'): 0.0017
# ('march', '18'): 0.0017
# ('18', ','): 0.0017
# (',', 'four'): 0.0016
# ('four', 'days'): 0.0017
# ('days', 'after'): 0.0017
# ('after', 'he'): 0.0021
# ('he', 'resigned'): 0.0017
# ('resigned', 'his'): 0.0017
# ('his', 'post'): 0.0017
# ('post', 'in'): 0.0017
# ('a', 'dispute'): 0.0016
# ('dispute', 'with'): 0.0017
# ('school', 'board'): 0.0017
# ('board', '.'): 0.0017
# ('<s>', 'during'): 0.0016
# ('during', 'the'): 0.0017
# ('election', 'campaign'): 0.0017
# ('campaign', ','): 0.0017
# (',', 'both'): 0.0016
# ('both', 'candidates'): 0.0017
# ('candidates', ','): 0.0017
# (',', 'davis'): 0.0016
# ('davis', 'and'): 0.0017
# (',', 'reportedly'): 0.0016
# ('reportedly', 'received'): 0.0017
# ('received', 'anonymous'): 0.0017
# ('anonymous', 'telephone'): 0.0017
# ('telephone', 'calls'): 0.0017
# ('calls', '.'): 0.0017
# ('ordinary', 'williams'): 0.0017
# ('said', 'he'): 0.0016
# ('he', ','): 0.0017
# (',', 'too'): 0.0016
# ('too', ','): 0.0017
# (',', 'was'): 0.0016
# ('was', 'subjected'): 0.0016
# ('subjected', 'to'): 0.0017
# ('to', 'anonymous'): 0.0016
# ('anonymous', 'calls'): 0.0017
# ('calls', 'soon'): 0.0017
# ('soon', 'after'): 0.0017
# ('he', 'scheduled'): 0.0017
# ('scheduled', 'the'): 0.0017
# ('election', '.'): 0.0021
# ('<s>', 'many'): 0.0016
# ('many', 'local'): 0.0017
# ('local', 'citizens'): 0.0017
# ('citizens', 'feared'): 0.0017
# ('feared', 'that'): 0.0017
# ('that', 'there'): 0.0016
# ('there', 'would'): 0.0017
# ('be', 'irregularities'): 0.0016
# ('irregularities', 'at'): 0.0017
# ('polls', ','): 0.0017
# ('and', 'williams'): 0.0016
# ('williams', 'got'): 0.0017
# ('got', 'himself'): 0.0017
# ('himself', 'a'): 0.0017
# ('a', 'permit'): 0.0016
# ('permit', 'to'): 0.0017
# ('to', 'carry'): 0.0016
# ('carry', 'a'): 0.0017
# ('a', 'gun'): 0.0016
# ('gun', 'and'): 0.0017
# ('and', 'promised'): 0.0016
# ('promised', 'an'): 0.0017
# ('orderly', 'election'): 0.0017
# ('<s>', 'sheriff'): 0.0016
# ('sheriff', 'felix'): 0.0017
# ('felix', 'tabb'): 0.0017
# ('tabb', 'said'): 0.0017
# ('said', 'the'): 0.0016
# ('the', 'ordinary'): 0.0016
# ('ordinary', 'apparently'): 0.0017
# ('apparently', 'made'): 0.0017
# ('made', 'good'): 0.0017
# ('good', 'his'): 0.0017
# ('his', 'promise'): 0.0017
# ('promise', '.'): 0.0017
# ('``', 'everything'): 0.0016
# ('everything', 'went'): 0.0017
# ('went', 'real'): 0.0017
# ('real', 'smooth'): 0.0017
# ('smooth', '``'): 0.0017
# ('the', 'sheriff'): 0.0016
# ('sheriff', 'said'): 0.0017
# ('was', "n't"): 0.0016
# ("n't", 'a'): 0.0017
# ('<s>', 'austin'): 0.0016
# ('austin', ','): 0.0017
# (',', 'texas'): 0.0016
# ('texas', '--'): 0.0017
# ('--', 'committee'): 0.0017
# ('committee', 'approval'): 0.0017
# ('approval', 'of'): 0.0017
# ('of', 'gov'): 0.0016
# ('<s>', 'price'): 0.0016
# ('price', 'daniel'): 0.0017
# ('daniel', "'s"): 0.0017
# ("'s", '``'): 0.0016
# ('``', 'abandoned'): 0.0016
# ('abandoned', 'property'): 0.0017
# ('property', '``'): 0.0017
# ('``', 'act'): 0.0016
# ('act', 'seemed'): 0.0017
# ('seemed', 'certain'): 0.0017
# ('certain', 'thursday'): 0.0017
# ('thursday', 'despite'): 0.0017
# ('the', 'adamant'): 0.0016
# ('adamant', 'protests'): 0.0017
# ('protests', 'of'): 0.0017
# ('of', 'texas'): 0.0016
# ('texas', 'bankers'): 0.0017
# ('bankers', '.'): 0.0017

# %% [markdown]
# ### Generating Text
# In this example, we generate text using the **bigrams** model by providing a starting **prompt** (e.g., "the jury"). The `generate_text` function creates a sequence of words based on the trained bigram model, starting from the provided prompt and continuing based on the probabilities of the next words.
#
# After tokenizing the corpus, generating bigrams, and calculating their frequencies and probabilities, the model uses these learned probabilities to generate text. The generated output is then written to a file.
#
# Text generation with n-grams helps illustrate how language models can predict word sequences, allowing us to create new sentences that follow similar patterns found in the original text.

# %%
import random

def generate_text(model: NGramModel, n: int, prompt: str, max_words: int = 20) -> str:
    generated_tokens = prompt.lower().split()

    for i in range(max_words):
        context = tuple(generated_tokens[-(n - 1):])

        next_words = {}
        for ngram, probability in model.probabilities.items():
            if ngram[:-1] == context:
                next_words[ngram[-1]] = probability

        if not next_words:
            break

        next_word = ''
        highest_prob = 0
        for word, probability in next_words.items():
            if probability > highest_prob:
                next_word = word
                highest_prob = probability


        if next_word == '</s>':
            break

        generated_tokens.append(next_word)

    return ' '.join(generated_tokens)

tokens = model.tokenize()
ngrams = model.generate_ngrams(tokens)
model.count_frequencies()
model.calculate_probabilities()
generated_text = generate_text(model, 2, 'the jury')
print(generated_text)
with open(f'./results/generated_bigrams.txt', 'w') as file_:
    file_.write(generated_text)
# Out:
# the jury said .

# %% [markdown]
# # A2.3

# %% [markdown]
# ## Word Vectors
# Based on the Stanford course: https://web.stanford.edu/class/cs224n/

# %% [markdown]
# ### Count based W2V
# In this section, we use the previously trained **n-gram model** to calculate a **co-occurrence matrix**. A co-occurrence matrix shows how often words appear together within a specific context (in this case, bigrams), providing insights into word relationships in the corpus.
#
# Steps:
# 1. **Tokenization and N-gram Generation**: We first tokenize the text and generate bigrams using the `NGramModel`.
# 2. **Vocabulary and Indexing**: The vocabulary is created from the unique tokens, and a word-to-index mapping is established.
# 3. **Co-occurrence Matrix**: Using the generated n-grams, we compute the co-occurrence matrix, where each entry represents how often two words occur together within the bigrams.
#
# The co-occurrence matrix provides a numerical representation of word relationships, which is useful for tasks like word embeddings, semantic analysis, and understanding word associations.

# %%
import pandas as pd

model = NGramModel(corpus, 2)
tokens = model.tokenize()
ngrams = model.generate_ngrams(tokens)

def create_co_matrix(ngrams: list, vocab_size: int, word_to_index: dict) -> np.ndarray:
    import numpy as np
    co_matrix = np.zeros((vocab_size, vocab_size), dtype=int)

    for ngram in ngrams:
            word1, word2 = ngram
            if word1 in word_to_index and word2 in word_to_index:
                i = word_to_index[word1]
                j = word_to_index[word2]
                co_matrix[i][j] += 1

    return co_matrix

vocab = list(set(word for sentence in tokens for word in sentence))
vocab_size = len(vocab)

word_to_index = {word: idx for idx, word in enumerate(vocab)}


co_matrix = create_co_matrix(ngrams, vocab_size, word_to_index)

# %% [markdown]
# With the code below you can verify if the co-occurence works

# %%
def check_co_occurrence(word1, word2, co_matrix, word_to_index):
    """
    Print the co-occurrence count for a specific word pair.
    """
    if word1 not in word_to_index or word2 not in word_to_index:
        print(f"One or both words '{word1}' and '{word2}' are not in the vocabulary.")
        return

    index1 = word_to_index[word1]
    index2 = word_to_index[word2]

    co_count = co_matrix[index1][index2]
    print(f"Co-occurrence count for '{word1}' and '{word2}': {co_count}")

check_co_occurrence('the', 'jury', co_matrix, word_to_index)
check_co_occurrence('the', 'cat', co_matrix, word_to_index)
# Out:
# Co-occurrence count for 'the' and 'jury': 13
# One or both words 'the' and 'cat' are not in the vocabulary.

# %% [markdown]
# In this part, we reduce the dimensionality of the **co-occurrence matrix** using **Singular Value Decomposition (SVD)**. This technique helps in extracting the most important features from the matrix, making it easier to visualize and interpret the relationships between words.
#
# Steps:
# 1. **Singular Value Decomposition (SVD)**: The co-occurrence matrix is decomposed into three matrices: \( M = U \cdot \Sigma \cdot V^T \).
# 2. **Dimensionality Reduction**: We retain only the top `k` components (default is 2) from the SVD, effectively reducing the dimensionality of the matrix.
# 3. **Reduced Matrix**: The reduced matrix retains the most important semantic information and can be used for tasks such as **word embedding visualization** or **semantic similarity analysis**.
#
# Dimensionality reduction allows us to capture the essence of word relationships in fewer dimensions, making it more efficient to process and visualize the data.

# %%
def reduce_to_k_dim(M, k=2):
    from sklearn.decomposition import TruncatedSVD

    svd = TruncatedSVD(n_components=k)
    M_reduced = svd.fit_transform(M)

    return M_reduced

# %% [markdown]
# In this final part, we visualize the reduced word embeddings in **2D space**. After reducing the dimensionality of the co-occurrence matrix using SVD, we plot the embeddings for each word to observe their relationships in a low-dimensional space.
#
# Steps:
# 1. **Plotting the Embeddings**: Each word from the vocabulary is plotted based on its 2D coordinates from the reduced matrix.
# 2. **Visualization**: The scatter plot allows us to see how words cluster together or relate to each other based on co-occurrences in the text. Words with similar contexts should appear closer to each other in the plot.
# 3. **Interpretation**: By looking at the 2D plot, we can analyze word similarities, relationships, and clusters formed by words that often occur together.
#
# This visualization is a useful tool for understanding the structure of word embeddings and the relationships between words in the corpus.

# %%
import matplotlib.pyplot as plt
def plot_embeddings(M_reduced, words):
    word_to_index = {word: i for i, word in enumerate(vocab)}

    words_in_vocab = [word for word in words if word in word_to_index]

    x_coordinates = [M_reduced[word_to_index[word]][0] for word in words_in_vocab]
    y_coordinates = [M_reduced[word_to_index[word]][1] for word in words_in_vocab]

    plt.figure(figsize=(10, 8))
    plt.scatter(x_coordinates, y_coordinates)

    for word, x, y in zip(words_in_vocab, x_coordinates, y_coordinates):
        plt.text(x, y, word, fontsize=9)

    plt.title("2D Word Embeddings from Co-occurrence Matrix (SVD)")
    plt.xlabel("SVD Component 1")
    plt.ylabel("SVD Component 2")
    plt.grid(True)
    plt.show()

#change of word list
words = ['grand', 'jury', 'investigation', 'election', 'irregularities',
    'judge', 'court', 'law', 'department', 'legislators',
    'mayor', 'funds', 'city', 'county']

M = create_co_matrix(ngrams, vocab_size, word_to_index)
M_reduced = reduce_to_k_dim(M, 2)
plot_embeddings(M_reduced, words)

# %% [markdown]
# ## Prediction-Based Word Vectors
# In this section, we load pre-trained word vectors using the **GloVe** embeddings from the [Stanford NLP paper on GloVe](https://nlp.stanford.edu/pubs/glove.pdf). The pre-trained embeddings provide rich semantic information about words based on large text corpora, allowing us to represent words as vectors that capture their meaning and relationships.
#
# Steps:
# 1. **Load GloVe Word Vectors**: We use the GloVe embeddings from the `glove-wiki-gigaword-200` model, which has 200-dimensional vectors for each word.
# 2. **Vocabulary Matching**: We map the words from our corpus to the GloVe vocabulary and extract the corresponding vectors.
# 3. **Dimensionality Reduction**: After obtaining the word vectors, we reduce the dimensionality to visualize the embeddings in 2D space, allowing us to explore word relationships visually.
#
# This is an excellent opportunity to explore how pre-trained embeddings like GloVe can be used to improve downstream NLP tasks by providing richer word representations.

# %%
#!pip install -q numpy==1.23.5 scipy==1.10.1 gensim==4.3.1 --force-reinstall --no-cache-dir

# %%
 #!pip install numpy==1.24.4
 #!pip install gensim

# %%
# Do not edit
import gensim.downloader as api
import numpy as np
wv_from_bin = api.load("glove-wiki-gigaword-200")
print("Loaded vocab size %i" % len(list(wv_from_bin.index_to_key)))

wv_words = list(wv_from_bin.index_to_key)
unique_tokens = set(word for sentence in tokens for word in sentence)
word2ind = {}
M = []
idx = 0
print('rendering M based on wv')
for w in wv_words:
    try:
        M.append(wv_from_bin.get_vector(w))
        word2ind[w] = idx
        idx += 1
    except:
        pass

print('rendering M based on unique_tokens')
for w in unique_tokens:
    if w in wv_words:
        continue
    try:
        M.append(wv_from_bin.get_vector(w))
        word2ind[w] = idx
        idx += 1
    except:
        pass
M = np.stack(M)
M_reduced = reduce_to_k_dim(M, k=2)

M_lengths = np.linalg.norm(M_reduced, axis=1)
M_reduced_normalized = M_reduced / M_lengths[:, np.newaxis]
print(M_reduced_normalized)
# Out:
# Loaded vocab size 400000
# rendering M based on wv
# rendering M based on unique_tokens
# [[ 0.9839149  -0.17863765]
#  [ 0.9850587   0.17221868]
#  [ 0.99598855 -0.08948034]
#  ...
#  [-0.99832445  0.05786423]
#  [-0.9901505   0.14000705]
#  [-0.9573135   0.28905183]]

# %% [markdown]
# ### Compare plots
# What stands out when comparing the two different ways of embedding using the given words?
#
# (Use this to help answer the question in your assignment document).
#
# When comparing the plot of count vectors and the plot of prediction vectors, it can be observed that the words in the count-vector plot, which is based on word counts, are more scattered and that the words in the plot of the prediction vectors, which is based on word prediction, are more grouped together. Additionally, the plot of prediction vectors shows that the legal-related words "law", "court", and "judge" are not as tightly clustered together as expected and are more spread out, but unrelated words such as "department" and "city" are appearing closer together. From this result, it can be concluded that the count-based methods only clusters on the co-occurrence of words but is therefore not always able to make functional clustering as it does not understand the deeper semantic meaning. In contrast, prediction-based methods cluster the legal terms (e.g. "judge", "legislators") tighter, which means that the model has been able to capture semantic relationship as it has learnt to group words with a similar role or meaning based on the context in which the words are appearing. However, it is not perfect, as seen in the plot of the prediction vectors, where, for example, the word "jury" is not clustered with the other legal terms.

# %%
plot_embeddings(M_reduced_normalized, words)

# %%
#print(wv_from_bin.most_similar('jury'))
# Out:
# [('jurors', 0.8326282501220703), ('verdict', 0.7091138362884521), ('juries', 0.6967692375183105), ('trial', 0.6840686202049255), ('prosecutors', 0.6517122983932495), ('judge', 0.6424550414085388), ('defendant', 0.6376617550849915), ('hearing', 0.6365344524383545), ('defendants', 0.6333721280097961), ('court', 0.6295028924942017)]

# %% [markdown]
# ### Words with multiple meanings
# Polysemes and homonyms are words that have more than one meaning (see [this wiki page](https://en.wikipedia.org/wiki/Polysemy) to learn more about the difference between polysemes and homonyms). Your task is to find a word with at least two different meanings such that the top-10 most similar words (according to cosine similarity) contain related words from both meanings.
#
# For example:
# - "leaves" has both the "go_away" and "a_structure_of_a_plant" meanings in the top 10.
# - "scoop" has both "handed_waffle_cone" and "lowdown" meanings in the top 10.
#
# You will probably need to try several polysemous or homonymic words before you find one.
#
# Once you discover a word that fits this criterion, state the word and explain the multiple meanings that occur in the top 10. Reflect on why many of the polysemous or homonymic words you tried didn’t work (i.e., why the top-10 most similar words only contain one of the word's meanings).
#
# **Note**: Use the `wv_from_bin.most_similar(word)` function to get the top 10 most similar words. This function ranks all other words in the vocabulary based on their cosine similarity to the given word. For further assistance, you can refer to the [Gensim documentation](https://radimrehurek.com/gensim/models/keyedvectors.html).

# %%
#https://www.yourdictionary.com/articles/words-multiple-meanings (crane double-meaning: bird and machine)

wv_from_bin.most_similar("crane")
# Out:
# [('cranes', 0.5964999198913574),
#  ('gantry', 0.5616371631622314),
#  ('sandhill', 0.5329699516296387),
#  ('sarus', 0.49083182215690613),
#  ('ichabod', 0.47095462679862976),
#  ('barge', 0.4651164412498474),
#  ('niles', 0.44390004873275757),
#  ('frasier', 0.4307387173175812),
#  ('whooping', 0.42178642749786377),
#  ('treadwheel', 0.4141821563243866)]

# %% [markdown]
# ## *Explanation Results:*

# %% [markdown]
# `The` word **"crane"** has a double meaning: "bird" and a "machine that lifts an object". As observed from the output, the top-10 most similar words according to the cosine similairy contained related words from both meanings of the word "crane". The words "sandhill", "sarus" and "whooping"  are related to the first definition "bird" and the words "gantry", "treadwheel", and "barge" are related to the second defition "machine that lifts an object".  This balanced results shows that the word "crane" is good example for a polysemous, as the the top similar words is balanced for both meanings. For other meanings, it can be the case that only one meaning is presented, which can be explained that the synonym words for the other meaning are not appearing frequent enough in the training data, leading to the model grouping one meaning in its context over another.

# %% [markdown]
# ### Synonyms
# When considering **Cosine Similarity**, it's often useful to think of **Cosine Distance**, which is simply 1 - Cosine Similarity.
#
# Find three words \( (w_1, w_2, w_3) \) where:
# - \(w_1\) and \(w_2\) are **synonyms**.
# - \(w_1\) and \(w_3\) are **antonyms**.
#
# However, you need to find a case where **Cosine Distance** \( (w_1, w_3) < \text{Cosine Distance} (w_1, w_2) \). In other words, the antonym is **closer** to the word than its synonym in the vector space.
#
# For example, "happy" (\(w_1\)) may be closer to "sad" (\(w_3\)) than to "cheerful" (\(w_2\)), which is counter-intuitive since we expect synonyms to be closer than antonyms.
#
# Once you find such an example, provide a possible explanation for why this result may have occurred.
#
# Use the `wv_from_bin.distance(w1, w2)` function to compute the cosine distance between two words. You can refer to the [Gensim documentation](https://radimrehurek.com/gensim/models/keyedvectors.html) for further assistance.

# %%
#example
#wv_from_bin.distance("happy", "cheerful")
#wv_from_bin.distance("happy", "sad")

print(wv_from_bin.distance("fast", "quick"))
print(wv_from_bin.distance("fast", "slow"))
# Out:
# 0.3328641653060913
# 0.2522680163383484

# %% [markdown]
# ## *Explanation Results:*

# %% [markdown]
# For this example the three words: **fast, quick and slow** are used. **fast** is w_1, **quick** is w_2, **slow** is w_3. **fast** and **quick** are synonyms and **fast** and **slow** are antonyms. As observed from the results the cosine distance from the antonyms is smaller (0.252) then the cosine distance from the synonyms (0.333), which means that in vector space the word **slow** is closer to the word **fast**, eventhough in langauge the two words share an opposite meaning. An explaination for this result can be that the antonyms are appearing in a similar context, which can lead to the result that the model is grouping them together, eventough both words share an opposite meaning.

# %% [markdown]
# ### Analogies
# Word vectors have demonstrated the ability to solve analogies based on their learned semantic relationships. For instance, consider the analogy:
#
# **"man : grandfather :: woman : x"**
#
# (Read: man is to grandfather as woman is to x). Using word vectors, we can find the word \(x\) that completes the analogy.
#
# In the example provided, we use the `most_similar` function from the Gensim library. This function identifies words that are most similar to the words in the positive list and most dissimilar to those in the negative list. For analogy solving, it effectively computes:
#
# \[ \text{word}(x) = \text{most similar to} (\text{woman} + \text{grandfather} - \text{man}) \]
#
# The result is the word with the highest cosine similarity to the target vector. You can use this approach to explore various analogies and gain insights into the semantic structure of word vectors.
#
# Refer to the [Gensim documentation](https://radimrehurek.com/gensim/models/keyedvectors.html) for more details on the `most_similar` function and how word vectors handle analogy-solving tasks.

# %%
# Run this cell to answer the analogy -- man : grandfather :: woman : x
print(wv_from_bin.most_similar(positive=['woman', 'grandfather'], negative=['man']))
# Out:
# [('grandmother', 0.7608445286750793), ('granddaughter', 0.7200808525085449), ('daughter', 0.7168302536010742), ('mother', 0.7151536345481873), ('niece', 0.7005682587623596), ('father', 0.6659887433052063), ('aunt', 0.6623408794403076), ('grandson', 0.6618767976760864), ('grandparents', 0.644661009311676), ('wife', 0.6445354223251343)]

# %% [markdown]
# ## *Explanation Results:*

# %% [markdown]
# This word vector searches for words that are most similar to the words in the positve list and most dissimalr to those in the negative list. For this example, the positive list contains the words woman and grandfather and the negative list contains the words man. With the use of the word vectors, the most similar word to a "female version" of the word "grandfather" is grandmather, as observed in the results as that is the higest ranked.

# %% [markdown]
# ### Bias in word vectors
# a. **Observation**: **Consider the results of a word vector model when queried with analogies involving "man", "woman", and "profession". What are the top results returned by the model for each query?**
#
# This word vector searches for words that are most similar to the words in the positve list and most dissimalr to those in the negative list. For the first query, the top 5 words that are similar to the word "profession" associated with man than female are: "reputation", "professions", "skill", "skills" and "ethnic". For the second query, the top 5 words that are simlar to the word "profession" associated with female than man are: "professions", "practitioner, "teaching", "nursing" and "vocation".
#
# b. **Analysis**: **Do you observe any gender biases in the results? For example, are certain professions more closely associated with "man" or "woman" based on the word vectors? Discuss how word embeddings might perpetuate societal biases present in the training data.**
#
#
# From the results gender biases can be observed, because the words that are similiar to "profession" for women are related to the education or care jobs, as words such as "teaching" and "nursing" and other related words are selected. The words similar to the word "profession" for men are more powerful than for the words related to femals, indicating that the similar words for males are more related to prestige professions as words such as "respected" and "reputation" are selected. This difference in results generatedby the model, indicates this gender bias as the model generates stereotyping results, indiacting that it must have been trained on text that included these sterotypes that male have high status professions and female more nurture-like professions. Word embeddings will also perpetuate these societal biases if they are presented in the training data, as they learn from a large text corpus and if that corpus includes text with these gender biases connecting professions nursing/education professions for woman and high-status/engineering prfofessions for man then the word embeddings will learn that these words often occur together, so it must have semantic relatedness and apply this in similar context, leadning to the repition of the sterotypes eventhough times have changed and the steortypes as well.
#
#
# c. **Reflection**: **How might such biases affect the fairness of machine learning models that use word embeddings? Suggest potential strategies for mitigating gender bias in word vector models.**
#
# These biases can have an affect of the fairness of ML models that use words embeddings, as when these models are applied in companies for hiring staff, then the ML models that use these biased word vectors will make these sterotype assoications of gender and the particualr profession [1]. So, this can lead to the model selecting a male candite for a particualr profession over a female candiate, as it has learned that a "respected" profession should be occupied by a male than a female, leading to unfair treatment and the growth of the inequalities between man and woman that has been going on for ages.
# Potential strategies for mitigrating gender bias in word vector models are to equally represent the male and female group and to add fairness rules during the training period, so that while the model is learning it will treath both groups equally and not give a preference to a particualr group.
#
# [1] Patel, P.: Ethical Issues of Word Embeddings: From Bias to Fairness. Medium (2024). https://medium.com/@prakul2003/ethical-issues-of-word-embeddings-from-bias-to-fairness-045041c2066d. Accessed 21 Apr 2025.

# %%
print(wv_from_bin.most_similar(positive=['man', 'profession'], negative=['woman']))
print()
print(wv_from_bin.most_similar(positive=['woman', 'profession'], negative=['man']))
# Out:
# [('reputation', 0.5250176787376404), ('professions', 0.5178037881851196), ('skill', 0.49046966433525085), ('skills', 0.49005505442619324), ('ethic', 0.4897659420967102), ('business', 0.4875852167606354), ('respected', 0.485920250415802), ('practice', 0.482104629278183), ('regarded', 0.4778572618961334), ('life', 0.4760662019252777)]
#
# [('professions', 0.5957457423210144), ('practitioner', 0.49884122610092163), ('teaching', 0.48292139172554016), ('nursing', 0.48211804032325745), ('vocation', 0.4788965880870819), ('teacher', 0.47160351276397705), ('practicing', 0.46937814354896545), ('educator', 0.46524327993392944), ('physicians', 0.4628995358943939), ('professionals', 0.4601394236087799)]
